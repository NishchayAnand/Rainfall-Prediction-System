# %%
import pandas as pd
import numpy as np
import random 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.contrib import rnn
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("C:/Users/win10/Desktop/Consecutive_month_data_for_lstm.xlsx")

# %%
df.head()
# Out:
#    Month1  Month2  Month3  Month4
# 0   5.303   3.075   1.303   0.013
# 1   3.075   1.303   0.013   1.948
# 2   1.303   0.013   1.948   1.023
# 3   0.013   1.948   1.023  12.881
# 4   1.948   1.023  12.881  29.374

# %%
# splitting the remaining data in training data and validation data.
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.2, shuffle = False)

# %%
df_train.index = range(df_train.shape[0])
df_test.index = range(df_test.shape[0])

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Month4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Month4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Month4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Month4"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (1101, 3)
# (1101, 1)
# (276, 3)
# (276, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Month4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# Reshaping the data into [samples, test_size, n_features] suitable for LSTM model.
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
#-----------------------------------------------------------------------------------------------------
# Definition for LSTM using tensorflow.

# %%
# defining hyper parameters for LSTM model.
epochs = 50
n_hidden = 50
n_features = 3
batch_size = 72
epoch_loss = []

# %%
# to reset tensorflow graph for every run.
tf.reset_default_graph()

# %%
# variables required for model creation.
x_data = tf.placeholder('float',[None,n_features,1])
y_target = tf.placeholder('float')

W = tf.Variable(tf.random_normal([n_hidden, 1]))
bias = tf.Variable(tf.random_normal([1]))

# 1-layer LSTM with n_hidden units.  
rnn_cell = rnn.BasicLSTMCell(n_hidden)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0814 12:47:54.932293 17780 deprecation.py:323] From <ipython-input-14-3804039b0bb1>:8: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.

# %%
def rnn_model(x):

    # Generate a n_input-element sequence of inputs
    # (eg. [had] [a] [general] -> [20] [6] [33])
    x = tf.unstack(x, n_features, 1)

    # generate prediction
    outputs, states = rnn.static_rnn(rnn_cell, x, dtype=tf.float32)

    # there are n_features outputs but
    # we only want the last output
    return (tf.matmul(outputs[-1], W) + bias)

# %%
# output equation of LSTM model.
y_predicted = tf.reshape(rnn_model(x_data),[-1])
# Out:
# W0814 12:47:55.119194 17780 deprecation.py:323] From <ipython-input-15-12c608517799>:12: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# W0814 12:47:55.145256 17780 deprecation.py:506] From c:\users\win10\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# W0814 12:47:55.162224 17780 deprecation.py:506] From c:\users\win10\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\rnn_cell_impl.py:738: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
# loss function = MSE (Mean Squared Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Adam as the optimization algorithm.
optimizer = tf.train.AdamOptimizer(0.01).minimize(cost)
#tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
sess.run(tf.local_variables_initializer())

# %%
for epoch in range(epochs):
    
        start = random.randint(0,(len(X_train)-batch_size))
        end = start + batch_size

        batch_x = np.array(X_train[start:end])
        batch_y = np.array(Y_train[start:end])
        
        # loop for training each batch.    
        for j in range(batch_x.shape[0]): 
            sess.run(optimizer, feed_dict={x_data: batch_x[j].reshape(1,3,1) , y_target: batch_y[j]})
        #loop for training each batch ends.       
            
        epoch_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
        
        print('Epoch', epoch, 'completed out of', epochs, 'Training_loss:', epoch_loss[epoch])
# Out:
# Epoch 0 completed out of 50 Training_loss: 0.037940294
# Epoch 1 completed out of 50 Training_loss: 0.04204327
# Epoch 2 completed out of 50 Training_loss: 0.04192415
# Epoch 3 completed out of 50 Training_loss: 0.046202943
# Epoch 4 completed out of 50 Training_loss: 0.04822059
# Epoch 5 completed out of 50 Training_loss: 0.043843772
# Epoch 6 completed out of 50 Training_loss: 0.043965086
# Epoch 7 completed out of 50 Training_loss: 0.050268736
# Epoch 8 completed out of 50 Training_loss: 0.055825524
# Epoch 9 completed out of 50 Training_loss: 0.04977888
# Epoch 10 completed out of 50 Training_loss: 0.052610308
# Epoch 11 completed out of 50 Training_loss: 0.057953794
# Epoch 12 completed out of 50 Training_loss: 0.04940842
# Epoch 13 completed out of 50 Training_loss: 0.058589138
# Epoch 14 completed out of 50 Training_loss: 0.05170306
# Epoch 15 completed out of 50 Training_loss: 0.056776393
# Epoch 16 completed out of 50 Training_loss: 0.055427082
# Epoch 17 completed out of 50 Training_loss: 0.053632364
# Epoch 18 completed out of 50 Training_loss: 0.049069386
# Epoch 19 completed out of 50 Training_loss: 0.05266838
# Epoch 20 completed out of 50 Training_loss: 0.057036087
# Epoch 21 completed out of 50 Training_loss: 0.049267277
# Epoch 22 completed out of 50 Training_loss: 0.06706899
# Epoch 23 completed out of 50 Training_loss: 0.049500927
# Epoch 24 completed out of 50 Training_loss: 0.05820786
# Epoch 25 completed out of 50 Training_loss: 0.05428715
# Epoch 26 completed out of 50 Training_loss: 0.04654418
# Epoch 27 completed out of 50 Training_loss: 0.052339647
# Epoch 28 completed out of 50 Training_loss: 0.054216616
# Epoch 29 completed out of 50 Training_loss: 0.049458172
# Epoch 30 completed out of 50 Training_loss: 0.047967013
# Epoch 31 completed out of 50 Training_loss: 0.059781883
# Epoch 32 completed out of 50 Training_loss: 0.05332895
# Epoch 33 completed out of 50 Training_loss: 0.053615488
# Epoch 34 completed out of 50 Training_loss: 0.060347337
# Epoch 35 completed out of 50 Training_loss: 0.053028252
# Epoch 36 completed out of 50 Training_loss: 0.049863823
# Epoch 37 completed out of 50 Training_loss: 0.043484926
# Epoch 38 completed out of 50 Training_loss: 0.06254455
# Epoch 39 completed out of 50 Training_loss: 0.06646727
# Epoch 40 completed out of 50 Training_loss: 0.047084972
# Epoch 41 completed out of 50 Training_loss: 0.04925241
# Epoch 42 completed out of 50 Training_loss: 0.046997756
# Epoch 43 completed out of 50 Training_loss: 0.054794587
# Epoch 44 completed out of 50 Training_loss: 0.05832294
# Epoch 45 completed out of 50 Training_loss: 0.053730596
# Epoch 46 completed out of 50 Training_loss: 0.057976287
# Epoch 47 completed out of 50 Training_loss: 0.055470258
# Epoch 48 completed out of 50 Training_loss: 0.053934604
# Epoch 49 completed out of 50 Training_loss: 0.048658457

# %%
# stores the predicted value for test data.
pred = sess.run(y_predicted, feed_dict={x_data:X_test})

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)
# Out:
# [1.549276] [0.652]
# [2.3606274] [1.507]

# %%
# plot showing difference between actual test data and predicted test data.
plt.figure(figsize=[20,8])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Prediction of monthly rainfall using LSTM model ')
plt.show()

# %%
# plot showing difference between actual test data and predicted test data for first 100 samples.
plt.figure(figsize=[20,8])
plt.plot(range(100),y_test[:100],label="Original Data")
plt.plot(range(100),pred[:100],label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Amount of Rainfall ')
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  2.266585708381635

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  3.471322716630886
