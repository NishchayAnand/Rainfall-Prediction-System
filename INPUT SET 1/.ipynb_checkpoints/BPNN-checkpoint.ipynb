# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("C:/Users/win10/Desktop/Consecutive_monthly_rainfall_intensity.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.4, shuffle = True)

# %%
df_train.index = range(df_train.shape[0])
df_test.index = range(df_test.shape[0])

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Month4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Month4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Month4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Month4"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (826, 3)
# (826, 1)
# (551, 3)
# (551, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Month4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
#-----------------------------------------------------------------------------------------------------

# %%
# defining weights and biases for the nn layers.

input_features = 3

W_1 = tf.Variable(tf.random_uniform([input_features,6])) # weights corresponding to first hidden/input layer.
b_1 = tf.Variable(tf.zeros([6]))

W_2 = tf.Variable(tf.random_uniform([6,6])) # weights corresponding to second hidden layer.
b_2 = tf.Variable(tf.zeros([6]))

W_O = tf.Variable(tf.random_uniform([6,1])) # weights corresponding to the output layer
b_O = tf.Variable(tf.zeros([1]))

# %%
def neural_net_model(X_data):
    
    # layer1 = relu(X_data.W_1 + b_1)
    layer_1 = tf.add(tf.matmul(X_data,W_1), b_1)
    layer_1 = tf.nn.relu(layer_1)
    
    # layer2 = relu(layer1.W_2 + b_2)
    layer_2 = tf.add(tf.matmul(layer_1,W_2), b_2)
    layer_2 = tf.nn.relu(layer_2)
    
    # output = layer2.W_O + b_O
    output = tf.add(tf.matmul(layer_2,W_O), b_O)
    
    return output

# %%
x_data = tf.placeholder("float")
y_target = tf.placeholder("float")

# %%
# y_predicted stores the predicted value.
y_predicted = neural_net_model(x_data)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size = 300

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the ANN regression model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,3), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.031040069
# Epoch : 1 Training Cost : 0.030954069
# Epoch : 2 Training Cost : 0.03065401
# Epoch : 3 Training Cost : 0.030372007
# Epoch : 4 Training Cost : 0.030208036
# Epoch : 5 Training Cost : 0.030947799
# Epoch : 6 Training Cost : 0.030119529
# Epoch : 7 Training Cost : 0.030194646
# Epoch : 8 Training Cost : 0.030236786
# Epoch : 9 Training Cost : 0.030006582
# Epoch : 10 Training Cost : 0.030100884
# Epoch : 11 Training Cost : 0.030037241
# Epoch : 12 Training Cost : 0.030061519
# Epoch : 13 Training Cost : 0.029874407
# Epoch : 14 Training Cost : 0.029565495
# Epoch : 15 Training Cost : 0.029131357
# Epoch : 16 Training Cost : 0.029212968
# Epoch : 17 Training Cost : 0.029235572
# Epoch : 18 Training Cost : 0.029029123
# Epoch : 19 Training Cost : 0.02917032
# Epoch : 20 Training Cost : 0.028368335
# Epoch : 21 Training Cost : 0.028402563
# Epoch : 22 Training Cost : 0.028702496
# Epoch : 23 Training Cost : 0.028418463
# Epoch : 24 Training Cost : 0.02775525
# Epoch : 25 Training Cost : 0.02762652
# Epoch : 26 Training Cost : 0.027776707
# Epoch : 27 Training Cost : 0.028861126
# Epoch : 28 Training Cost : 0.027120905
# Epoch : 29 Training Cost : 0.026705537
# Epoch : 30 Training Cost : 0.026367024
# Epoch : 31 Training Cost : 0.026137572
# Epoch : 32 Training Cost : 0.02575487
# Epoch : 33 Training Cost : 0.025334505
# Epoch : 34 Training Cost : 0.025581697
# Epoch : 35 Training Cost : 0.024447983
# Epoch : 36 Training Cost : 0.02438947
# Epoch : 37 Training Cost : 0.023375358
# Epoch : 38 Training Cost : 0.02331637
# Epoch : 39 Training Cost : 0.022459676
# Epoch : 40 Training Cost : 0.021649893
# Epoch : 41 Training Cost : 0.02266775
# Epoch : 42 Training Cost : 0.021119772
# Epoch : 43 Training Cost : 0.020604858
# Epoch : 44 Training Cost : 0.02030888
# Epoch : 45 Training Cost : 0.020109855
# Epoch : 46 Training Cost : 0.02062183
# Epoch : 47 Training Cost : 0.020149771
# Epoch : 48 Training Cost : 0.019521248
# Epoch : 49 Training Cost : 0.019591188
# Epoch : 50 Training Cost : 0.021164637
# Epoch : 51 Training Cost : 0.019162972
# Epoch : 52 Training Cost : 0.019147707
# Epoch : 53 Training Cost : 0.019158132
# Epoch : 54 Training Cost : 0.018870097
# Epoch : 55 Training Cost : 0.018859288
# Epoch : 56 Training Cost : 0.019025689
# Epoch : 57 Training Cost : 0.018787295
# Epoch : 58 Training Cost : 0.018924583
# Epoch : 59 Training Cost : 0.018538304
# Epoch : 60 Training Cost : 0.019166702
# Epoch : 61 Training Cost : 0.018512787
# Epoch : 62 Training Cost : 0.018278148
# Epoch : 63 Training Cost : 0.018415453
# Epoch : 64 Training Cost : 0.01847026
# Epoch : 65 Training Cost : 0.018257538
# Epoch : 66 Training Cost : 0.018257631
# Epoch : 67 Training Cost : 0.020934097
# Epoch : 68 Training Cost : 0.018629877
# Epoch : 69 Training Cost : 0.01820448
# Epoch : 70 Training Cost : 0.018581219
# Epoch : 71 Training Cost : 0.018063419
# Epoch : 72 Training Cost : 0.01807017
# Epoch : 73 Training Cost : 0.01797418
# Epoch : 74 Training Cost : 0.018091068
# Epoch : 75 Training Cost : 0.01848054
# Epoch : 76 Training Cost : 0.018145861
# Epoch : 77 Training Cost : 0.020211268
# Epoch : 78 Training Cost : 0.020031646
# Epoch : 79 Training Cost : 0.01868648
# Epoch : 80 Training Cost : 0.017948205
# Epoch : 81 Training Cost : 0.018238664
# Epoch : 82 Training Cost : 0.018486213
# Epoch : 83 Training Cost : 0.018042022
# Epoch : 84 Training Cost : 0.017829917
# Epoch : 85 Training Cost : 0.018058859
# Epoch : 86 Training Cost : 0.018040428
# Epoch : 87 Training Cost : 0.017959649
# Epoch : 88 Training Cost : 0.018770885
# Epoch : 89 Training Cost : 0.018491713
# Epoch : 90 Training Cost : 0.01785536
# Epoch : 91 Training Cost : 0.018123528
# Epoch : 92 Training Cost : 0.01776604
# Epoch : 93 Training Cost : 0.01776786
# Epoch : 94 Training Cost : 0.017755512
# Epoch : 95 Training Cost : 0.018207025
# Epoch : 96 Training Cost : 0.01848358
# Epoch : 97 Training Cost : 0.017832996
# Epoch : 98 Training Cost : 0.019792123
# Epoch : 99 Training Cost : 0.018386068
# Test Data Cost : 0.029303415

# %%
# stores the predicted value for test data using trained ANN model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[20,8])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Amount of Rainfall ')
plt.show()

# %%
# plot showing difference between actual test data and predicted test data for first 100 samples.
plt.figure(figsize=[20,8])
plt.plot(range(100),y_test[:100],label="Original Data")
plt.plot(range(100),pred[:100],label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Amount of Rainfall ')
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  90.83030110651698

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  155.87869050482956
