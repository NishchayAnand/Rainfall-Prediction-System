# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("INPUT SET 1.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
df_train.index = range(df_train.shape[0])
df_test.index = range(df_test.shape[0])

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Month4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Month4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Month4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Month4"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (963, 3)
# (963, 1)
# (414, 3)
# (414, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Month4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
#-----------------------------------------------------------------------------------------------------

# %%
# defining weights and biases for the nn layers.

input_features = 3

W_1 = tf.Variable(tf.random_uniform([input_features,6])) # weights corresponding to first hidden/input layer.
b_1 = tf.Variable(tf.zeros([6]))

W_2 = tf.Variable(tf.random_uniform([6,6])) # weights corresponding to second hidden layer.
b_2 = tf.Variable(tf.zeros([6]))

W_O = tf.Variable(tf.random_uniform([6,1])) # weights corresponding to the output layer
b_O = tf.Variable(tf.zeros([1]))

# %%
def neural_net_model(X_data):
    
    # layer1 = relu(X_data.W_1 + b_1)
    layer_1 = tf.add(tf.matmul(X_data,W_1), b_1)
    layer_1 = tf.nn.relu(layer_1)
    
    # layer2 = relu(layer1.W_2 + b_2)
    layer_2 = tf.add(tf.matmul(layer_1,W_2), b_2)
    layer_2 = tf.nn.relu(layer_2)
    
    # output = layer2.W_O + b_O
    output = tf.add(tf.matmul(layer_2,W_O), b_O)
    
    return output

# %%
x_data = tf.placeholder("float")
y_target = tf.placeholder("float")

# %%
# y_predicted stores the predicted value.
y_predicted = neural_net_model(x_data)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size = 300

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the ANN regression model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,3), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.03836966
# Epoch : 1 Training Cost : 0.03553118
# Epoch : 2 Training Cost : 0.03560283
# Epoch : 3 Training Cost : 0.033994645
# Epoch : 4 Training Cost : 0.032760836
# Epoch : 5 Training Cost : 0.03171082
# Epoch : 6 Training Cost : 0.029683257
# Epoch : 7 Training Cost : 0.027978782
# Epoch : 8 Training Cost : 0.026430486
# Epoch : 9 Training Cost : 0.026016643
# Epoch : 10 Training Cost : 0.02530805
# Epoch : 11 Training Cost : 0.023804318
# Epoch : 12 Training Cost : 0.022604682
# Epoch : 13 Training Cost : 0.022445044
# Epoch : 14 Training Cost : 0.022068668
# Epoch : 15 Training Cost : 0.021488251
# Epoch : 16 Training Cost : 0.021651426
# Epoch : 17 Training Cost : 0.021359744
# Epoch : 18 Training Cost : 0.021163974
# Epoch : 19 Training Cost : 0.021243697
# Epoch : 20 Training Cost : 0.020848598
# Epoch : 21 Training Cost : 0.021195047
# Epoch : 22 Training Cost : 0.023531554
# Epoch : 23 Training Cost : 0.020711249
# Epoch : 24 Training Cost : 0.020542365
# Epoch : 25 Training Cost : 0.02060786
# Epoch : 26 Training Cost : 0.02207898
# Epoch : 27 Training Cost : 0.020373551
# Epoch : 28 Training Cost : 0.020233067
# Epoch : 29 Training Cost : 0.020976292
# Epoch : 30 Training Cost : 0.020075748
# Epoch : 31 Training Cost : 0.020208955
# Epoch : 32 Training Cost : 0.020369345
# Epoch : 33 Training Cost : 0.020051496
# Epoch : 34 Training Cost : 0.021184402
# Epoch : 35 Training Cost : 0.019919418
# Epoch : 36 Training Cost : 0.019780029
# Epoch : 37 Training Cost : 0.019993715
# Epoch : 38 Training Cost : 0.019869417
# Epoch : 39 Training Cost : 0.01966383
# Epoch : 40 Training Cost : 0.020184258
# Epoch : 41 Training Cost : 0.01980774
# Epoch : 42 Training Cost : 0.020326992
# Epoch : 43 Training Cost : 0.019464822
# Epoch : 44 Training Cost : 0.019900283
# Epoch : 45 Training Cost : 0.02157159
# Epoch : 46 Training Cost : 0.02130203
# Epoch : 47 Training Cost : 0.019329235
# Epoch : 48 Training Cost : 0.019365799
# Epoch : 49 Training Cost : 0.019367127
# Epoch : 50 Training Cost : 0.0195425
# Epoch : 51 Training Cost : 0.019278394
# Epoch : 52 Training Cost : 0.01941985
# Epoch : 53 Training Cost : 0.01915312
# Epoch : 54 Training Cost : 0.01905226
# Epoch : 55 Training Cost : 0.019544724
# Epoch : 56 Training Cost : 0.019217955
# Epoch : 57 Training Cost : 0.02198008
# Epoch : 58 Training Cost : 0.018969614
# Epoch : 59 Training Cost : 0.019626906
# Epoch : 60 Training Cost : 0.019060364
# Epoch : 61 Training Cost : 0.019653048
# Epoch : 62 Training Cost : 0.01889145
# Epoch : 63 Training Cost : 0.019063719
# Epoch : 64 Training Cost : 0.01911081
# Epoch : 65 Training Cost : 0.018795962
# Epoch : 66 Training Cost : 0.020935694
# Epoch : 67 Training Cost : 0.0188926
# Epoch : 68 Training Cost : 0.01882053
# Epoch : 69 Training Cost : 0.019202873
# Epoch : 70 Training Cost : 0.018915715
# Epoch : 71 Training Cost : 0.019214973
# Epoch : 72 Training Cost : 0.018647095
# Epoch : 73 Training Cost : 0.019348325
# Epoch : 74 Training Cost : 0.018589268
# Epoch : 75 Training Cost : 0.018528325
# Epoch : 76 Training Cost : 0.018678144
# Epoch : 77 Training Cost : 0.018542854
# Epoch : 78 Training Cost : 0.018701248
# Epoch : 79 Training Cost : 0.018462041
# Epoch : 80 Training Cost : 0.018715935
# Epoch : 81 Training Cost : 0.01850918
# Epoch : 82 Training Cost : 0.019736065
# Epoch : 83 Training Cost : 0.018569062
# Epoch : 84 Training Cost : 0.01846485
# Epoch : 85 Training Cost : 0.01849877
# Epoch : 86 Training Cost : 0.018413087
# Epoch : 87 Training Cost : 0.020312022
# Epoch : 88 Training Cost : 0.018359188
# Epoch : 89 Training Cost : 0.020154074
# Epoch : 90 Training Cost : 0.018340938
# Epoch : 91 Training Cost : 0.019348022
# Epoch : 92 Training Cost : 0.019530572
# Epoch : 93 Training Cost : 0.01839205
# Epoch : 94 Training Cost : 0.018322019
# Epoch : 95 Training Cost : 0.018448653
# Epoch : 96 Training Cost : 0.018303327
# Epoch : 97 Training Cost : 0.018302789
# Epoch : 98 Training Cost : 0.018217128
# Epoch : 99 Training Cost : 0.01820875
# Test Data Cost : 0.021767557

# %%
# stores the predicted value for test data using trained ANN model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[10,5])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall (in mm) ', fontsize="14")
plt.xlabel('Time (Months)',fontsize="14")
plt.show()

# %%
# plot showing difference between actual test data and predicted test data for first 100 samples.
plt.figure(figsize=[10,5])
plt.plot(range(100),y_test[:100],label="Original Data")
plt.plot(range(100),pred[:100],label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Amount of Rainfall ')
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  76.02988259965095

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  119.1814574529528

# %%
plt.figure(figsize=[10,5])
plt.plot(range(len(train_loss)),train_loss,label="Training loss")
plt.plot(range(len(test_loss)),test_loss,label="testing loss")
plt.legend(loc='best')
plt.ylabel('Mean Square Error (MSE)')
plt.xlabel('Number of iterations')
plt.title('Loss function')
plt.show()
