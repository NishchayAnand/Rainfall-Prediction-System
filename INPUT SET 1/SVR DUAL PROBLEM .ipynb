# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("INPUT SET 1.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.4, shuffle = True)

# %%
df_train.index = range(df_train.shape[0])
df_test.index = range(df_test.shape[0])

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Month4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Month4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Month4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Month4"].values.reshape(-1,1))

# %%
# function to denormalize the obtained output.
def denormalize(df,norm_data):
    df = df["Month4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
#-----------------------------------------------------------------------------------------------------
# SVR using kernel definition.

# %%
# defining variables and parameters used for model definition and training.
batch_size = 50
epochs = 100
x_data = tf.placeholder(shape=[None, 3], dtype=tf.float32)
y_target = tf.placeholder(shape=[None, 1], dtype=tf.float32)
prediction_data = tf.placeholder(shape=[None, 3], dtype=tf.float32)
b = tf.Variable(tf.zeros(shape=[1,batch_size]))

# %%
indices = np.random.choice(len(X_train), batch_size)

# %%
# kernel definition.(linear, polynomial, RBF)

def kernel(kernel_name):
    if(kernel_name == "rbf"):
        gamma = tf.constant(-1.)
        # rA = X_data^2 having shape = [batch_size,1]
        rA = tf.reshape(tf.reduce_sum(tf.square(x_data), 1),[-1,1]) 
        # rB = prediction_data^2 having shape = [prediction_sample,1]
        rB = tf.reshape(tf.reduce_sum(tf.square(prediction_data), 1),[-1,1])
        # pred_sq_list gives the square distance between prediction_data and every other X_data's samples.
        # pred_sq_list = X^2 - 2.X.Xi + Xi^2
        pred_sq_dist = tf.add(tf.subtract(rA, tf.multiply(2., tf.matmul(x_data,tf.transpose(prediction_data)))), tf.transpose(rB))
        #pred_kernel = exp(-gamma*(||X-Xi||**2))
        pred_kernel = tf.exp(tf.multiply(gamma, tf.abs(pred_sq_dist))) 
        
    elif(kernel_name == "poly"):
        degree = tf.constant(2.0)
        # pred_kernel = (1+X.Xi)**2
        pred_kernel = (tf.add(1.0, tf.matmul(x_data,tf.transpose(prediction_data))))**degree
        
    else:
        #pred_kernel = X.Xi
        pred_kernel = tf.matmul(x_data,tf.transpose(prediction_data))
        
    return pred_kernel

# %%
my_kernel = kernel("rbf")

# %%
# output hyperplane 
y_predicted = tf.matmul(b, my_kernel)

# %%
# definition for the loss function.
epsilon = tf.constant([0.08])
# b_vec_cross = bi.bj having shape [batch_size, batch_size]
b_vec_cross = tf.matmul(tf.transpose(b),b)
#first_term = summation of 1/2*bi.bj*k(xi,xj)
first_term = tf.reduce_sum(tf.multiply(0.5,tf.multiply(b_vec_cross, my_kernel)))
# second_term = summation of |bi|*epsilon
second_term = tf.multiply(epsilon,tf.reduce_sum(tf.abs(b)))
# third_term = summation of bi.yi
third_term = tf.matmul(b, y_target)
#loss = first_term + second_term - third_term
loss = tf.subtract(tf.add(first_term, second_term), third_term)

# %%
train = tf.train.GradientDescentOptimizer(0.01).minimize(loss)

# %%
train_loss = []
test_loss = []

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# loop for training SVR model.

for i in range(epochs):
        
    train_indices = np.random.choice(len(X_train), batch_size)
    x_train = X_train[train_indices]
    y_train = Y_train[train_indices]
    test_indices = np.random.choice(len(X_test), batch_size)
    x_test = X_test[test_indices]
    y_test = Y_test[test_indices]
    
    for j in range(x_train.shape[0]):
        sess.run(train,feed_dict={x_data:x_train, y_target:y_train, prediction_data:x_train[j,:].reshape(1,3)})
    
    train_loss.append(sess.run(loss,feed_dict={x_data:x_train, y_target:y_train, prediction_data:x_train}))
    test_loss.append(sess.run(loss, feed_dict={x_data:x_test, y_target:y_test, prediction_data:x_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
        
# end of for loop for training the model.
# Out:
# Epoch : 0 Training Cost : [[-0.31177002]]
# Epoch : 1 Training Cost : [[-0.20886284]]
# Epoch : 2 Training Cost : [[-0.20139581]]
# Epoch : 3 Training Cost : [[-0.30434993]]
# Epoch : 4 Training Cost : [[-0.31907701]]
# Epoch : 5 Training Cost : [[-0.13328958]]
# Epoch : 6 Training Cost : [[-0.3052935]]
# Epoch : 7 Training Cost : [[-0.1773178]]
# Epoch : 8 Training Cost : [[-0.03245151]]
# Epoch : 9 Training Cost : [[-0.48656654]]
# Epoch : 10 Training Cost : [[-0.0560208]]
# Epoch : 11 Training Cost : [[-0.03466964]]
# Epoch : 12 Training Cost : [[0.1144886]]
# Epoch : 13 Training Cost : [[0.04079494]]
# Epoch : 14 Training Cost : [[-0.29073054]]
# Epoch : 15 Training Cost : [[-0.23634887]]
# Epoch : 16 Training Cost : [[0.06590044]]
# Epoch : 17 Training Cost : [[-0.2847355]]
# Epoch : 18 Training Cost : [[-0.08013442]]
# Epoch : 19 Training Cost : [[-0.26054394]]
# Epoch : 20 Training Cost : [[-0.35456914]]
# Epoch : 21 Training Cost : [[-0.25101006]]
# Epoch : 22 Training Cost : [[-0.20450103]]
# Epoch : 23 Training Cost : [[-0.18647403]]
# Epoch : 24 Training Cost : [[0.23147646]]
# Epoch : 25 Training Cost : [[-0.14638811]]
# Epoch : 26 Training Cost : [[-0.4542526]]
# Epoch : 27 Training Cost : [[-0.35528904]]
# Epoch : 28 Training Cost : [[0.02917528]]
# Epoch : 29 Training Cost : [[0.06286889]]
# Epoch : 30 Training Cost : [[0.08795515]]
# Epoch : 31 Training Cost : [[-0.16553071]]
# Epoch : 32 Training Cost : [[-0.18369916]]
# Epoch : 33 Training Cost : [[0.14397854]]
# Epoch : 34 Training Cost : [[-0.20599899]]
# Epoch : 35 Training Cost : [[-0.0975616]]
# Epoch : 36 Training Cost : [[-0.41871524]]
# Epoch : 37 Training Cost : [[0.01997739]]
# Epoch : 38 Training Cost : [[-0.2806114]]
# Epoch : 39 Training Cost : [[0.06223965]]
# Epoch : 40 Training Cost : [[-0.3195088]]
# Epoch : 41 Training Cost : [[0.05624476]]
# Epoch : 42 Training Cost : [[-0.09390312]]
# Epoch : 43 Training Cost : [[-0.35369122]]
# Epoch : 44 Training Cost : [[0.03269082]]
# Epoch : 45 Training Cost : [[0.10435838]]
# Epoch : 46 Training Cost : [[-0.04691458]]
# Epoch : 47 Training Cost : [[-0.09036544]]
# Epoch : 48 Training Cost : [[-0.27677727]]
# Epoch : 49 Training Cost : [[-0.31401885]]
# Epoch : 50 Training Cost : [[0.10564405]]
# Epoch : 51 Training Cost : [[0.20320944]]
# Epoch : 52 Training Cost : [[-0.08461732]]
# Epoch : 53 Training Cost : [[0.0741477]]
# Epoch : 54 Training Cost : [[-0.23009819]]
# Epoch : 55 Training Cost : [[-0.12960577]]
# Epoch : 56 Training Cost : [[-0.16250938]]
# Epoch : 57 Training Cost : [[-0.2259081]]
# Epoch : 58 Training Cost : [[-0.22097668]]
# Epoch : 59 Training Cost : [[-0.05875558]]
# Epoch : 60 Training Cost : [[-0.55085146]]
# Epoch : 61 Training Cost : [[0.34264517]]
# Epoch : 62 Training Cost : [[-0.08166301]]
# Epoch : 63 Training Cost : [[0.3052262]]
# Epoch : 64 Training Cost : [[-0.15637636]]
# Epoch : 65 Training Cost : [[-0.0358007]]
# Epoch : 66 Training Cost : [[0.11551076]]
# Epoch : 67 Training Cost : [[-0.37094963]]
# Epoch : 68 Training Cost : [[0.02953798]]
# Epoch : 69 Training Cost : [[-0.01305175]]
# Epoch : 70 Training Cost : [[-0.14561445]]
# Epoch : 71 Training Cost : [[0.08454782]]
# Epoch : 72 Training Cost : [[-0.35565305]]
# Epoch : 73 Training Cost : [[-0.04537284]]
# Epoch : 74 Training Cost : [[0.23660663]]
# Epoch : 75 Training Cost : [[0.09036981]]
# Epoch : 76 Training Cost : [[-0.18073201]]
# Epoch : 77 Training Cost : [[-0.1456086]]
# Epoch : 78 Training Cost : [[-0.41208243]]
# Epoch : 79 Training Cost : [[-0.038544]]
# Epoch : 80 Training Cost : [[-0.1079202]]
# Epoch : 81 Training Cost : [[-0.36819184]]
# Epoch : 82 Training Cost : [[-0.01986626]]
# Epoch : 83 Training Cost : [[-0.33045506]]
# Epoch : 84 Training Cost : [[-0.22791946]]
# Epoch : 85 Training Cost : [[-0.3106165]]
# Epoch : 86 Training Cost : [[-0.13630235]]
# Epoch : 87 Training Cost : [[-0.03387207]]
# Epoch : 88 Training Cost : [[-0.11486608]]
# Epoch : 89 Training Cost : [[-0.11658233]]
# Epoch : 90 Training Cost : [[-0.18034679]]
# Epoch : 91 Training Cost : [[-0.12789857]]
# Epoch : 92 Training Cost : [[0.00958365]]
# Epoch : 93 Training Cost : [[0.10662258]]
# Epoch : 94 Training Cost : [[-0.23700494]]
# Epoch : 95 Training Cost : [[-0.0113776]]
# Epoch : 96 Training Cost : [[-0.09399191]]
# Epoch : 97 Training Cost : [[-0.19199419]]
# Epoch : 98 Training Cost : [[-0.39324224]]
# Epoch : 99 Training Cost : [[-0.5084298]]

# %%
x = X_train[indices]
# predicting ouput for X_test.
pred = sess.run(y_predicted, feed_dict={x_data:x, prediction_data:X_test})

# %%
# denormalizing Y_test and corresponding predicted output.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data.
plt.figure(figsize=[20,8])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Output of SVR (using linear kernel) ')
plt.show()

# %%
# Mean absolute Error.
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  141.20086382236164

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  207.26350793479943
