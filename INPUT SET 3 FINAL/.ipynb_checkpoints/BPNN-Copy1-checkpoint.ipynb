# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("InputSet3.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Y"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Y"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Y"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Y"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (940, 4)
# (940, 1)
# (404, 4)
# (404, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Y"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# defining weights and biases for the nn layers.

input_features = 4

W_1 = tf.Variable(tf.random_uniform([input_features,6])) # weights corresponding to first hidden/input layer.
b_1 = tf.Variable(tf.zeros([6]))

W_2 = tf.Variable(tf.random_uniform([6,6])) # weights corresponding to second hidden layer.
b_2 = tf.Variable(tf.zeros([6]))

W_O = tf.Variable(tf.random_uniform([6,1])) # weights corresponding to the output layer
b_O = tf.Variable(tf.zeros([1]))

# %%
def neural_net_model(X_data):
    
    # layer1 = relu(X_data.W_1 + b_1)
    layer_1 = tf.add(tf.matmul(X_data,W_1), b_1)
    layer_1 = tf.nn.relu(layer_1)
    
    # layer2 = relu(layer1.W_2 + b_2)
    layer_2 = tf.add(tf.matmul(layer_1,W_2), b_2)
    layer_2 = tf.nn.relu(layer_2)
    
    # output = layer2.W_O + b_O
    output = tf.add(tf.matmul(layer_2,W_O), b_O)
    
    return output

# %%
x_data = tf.placeholder("float")
y_target = tf.placeholder("float")

# %%
# y_predicted stores the predicted value.
y_predicted = neural_net_model(x_data)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size =  100

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the ANN regression model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,4), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.064932786
# Epoch : 1 Training Cost : 0.041206863
# Epoch : 2 Training Cost : 0.037220407
# Epoch : 3 Training Cost : 0.03470677
# Epoch : 4 Training Cost : 0.033252604
# Epoch : 5 Training Cost : 0.032431953
# Epoch : 6 Training Cost : 0.032791294
# Epoch : 7 Training Cost : 0.03225861
# Epoch : 8 Training Cost : 0.031184033
# Epoch : 9 Training Cost : 0.030650647
# Epoch : 10 Training Cost : 0.030645538
# Epoch : 11 Training Cost : 0.030490784
# Epoch : 12 Training Cost : 0.029607294
# Epoch : 13 Training Cost : 0.028250303
# Epoch : 14 Training Cost : 0.029021204
# Epoch : 15 Training Cost : 0.027168144
# Epoch : 16 Training Cost : 0.026211265
# Epoch : 17 Training Cost : 0.025559926
# Epoch : 18 Training Cost : 0.025020663
# Epoch : 19 Training Cost : 0.024628762
# Epoch : 20 Training Cost : 0.024066083
# Epoch : 21 Training Cost : 0.023102853
# Epoch : 22 Training Cost : 0.022846695
# Epoch : 23 Training Cost : 0.02171714
# Epoch : 24 Training Cost : 0.021550654
# Epoch : 25 Training Cost : 0.02127
# Epoch : 26 Training Cost : 0.02095974
# Epoch : 27 Training Cost : 0.019689215
# Epoch : 28 Training Cost : 0.018881898
# Epoch : 29 Training Cost : 0.0186317
# Epoch : 30 Training Cost : 0.01787052
# Epoch : 31 Training Cost : 0.017409451
# Epoch : 32 Training Cost : 0.017206078
# Epoch : 33 Training Cost : 0.016601846
# Epoch : 34 Training Cost : 0.016317114
# Epoch : 35 Training Cost : 0.016851963
# Epoch : 36 Training Cost : 0.015882403
# Epoch : 37 Training Cost : 0.015753716
# Epoch : 38 Training Cost : 0.015413839
# Epoch : 39 Training Cost : 0.01532959
# Epoch : 40 Training Cost : 0.0151895955
# Epoch : 41 Training Cost : 0.014882216
# Epoch : 42 Training Cost : 0.014721306
# Epoch : 43 Training Cost : 0.014521317
# Epoch : 44 Training Cost : 0.014233909
# Epoch : 45 Training Cost : 0.014276343
# Epoch : 46 Training Cost : 0.013929461
# Epoch : 47 Training Cost : 0.013796497
# Epoch : 48 Training Cost : 0.013542823
# Epoch : 49 Training Cost : 0.013189191
# Epoch : 50 Training Cost : 0.013214857
# Epoch : 51 Training Cost : 0.013024515
# Epoch : 52 Training Cost : 0.013026282
# Epoch : 53 Training Cost : 0.013327036
# Epoch : 54 Training Cost : 0.012792235
# Epoch : 55 Training Cost : 0.014109202
# Epoch : 56 Training Cost : 0.012728341
# Epoch : 57 Training Cost : 0.013318664
# Epoch : 58 Training Cost : 0.013679024
# Epoch : 59 Training Cost : 0.01265956
# Epoch : 60 Training Cost : 0.012335444
# Epoch : 61 Training Cost : 0.012321834
# Epoch : 62 Training Cost : 0.012773639
# Epoch : 63 Training Cost : 0.012548412
# Epoch : 64 Training Cost : 0.012355662
# Epoch : 65 Training Cost : 0.012497988
# Epoch : 66 Training Cost : 0.0127733555
# Epoch : 67 Training Cost : 0.012087026
# Epoch : 68 Training Cost : 0.012105134
# Epoch : 69 Training Cost : 0.01255002
# Epoch : 70 Training Cost : 0.01216615
# Epoch : 71 Training Cost : 0.0121409865
# Epoch : 72 Training Cost : 0.011880673
# Epoch : 73 Training Cost : 0.012068305
# Epoch : 74 Training Cost : 0.011843072
# Epoch : 75 Training Cost : 0.012475989
# Epoch : 76 Training Cost : 0.011894393
# Epoch : 77 Training Cost : 0.011879446
# Epoch : 78 Training Cost : 0.012040182
# Epoch : 79 Training Cost : 0.011835629
# Epoch : 80 Training Cost : 0.011632263
# Epoch : 81 Training Cost : 0.011796767
# Epoch : 82 Training Cost : 0.012377445
# Epoch : 83 Training Cost : 0.011639969
# Epoch : 84 Training Cost : 0.011515108
# Epoch : 85 Training Cost : 0.011511515
# Epoch : 86 Training Cost : 0.011812315
# Epoch : 87 Training Cost : 0.0114666475
# Epoch : 88 Training Cost : 0.011509454
# Epoch : 89 Training Cost : 0.011455145
# Epoch : 90 Training Cost : 0.011517194
# Epoch : 91 Training Cost : 0.011435192
# Epoch : 92 Training Cost : 0.011656743
# Epoch : 93 Training Cost : 0.0113511095
# Epoch : 94 Training Cost : 0.0114977965
# Epoch : 95 Training Cost : 0.01180816
# Epoch : 96 Training Cost : 0.011397769
# Epoch : 97 Training Cost : 0.011297543
# Epoch : 98 Training Cost : 0.011343755
# Epoch : 99 Training Cost : 0.011253735
# Test Data Cost : 0.013681296

# %%
# stores the predicted value for test data using trained ANN model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Intensity of Rainfall (in mm) ', fontsize="14")
plt.xlabel('Time (Months)', fontsize="14")
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  56.372510158425506

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  94.48599735736522

# %%
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(len(train_loss)),train_loss,label="Training loss")
plt.plot(range(len(test_loss)),test_loss,label="testing loss")
plt.legend(loc='best')
plt.ylabel('Mean Square Error (MSE)', fontsize="14")
plt.xlabel('Number of iterations', fontsize="14")
plt.show()
