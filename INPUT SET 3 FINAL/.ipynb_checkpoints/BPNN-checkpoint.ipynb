# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("InputSet3.xlsx")

# %%
df.head()
# Out:
#      X1    X2    X3    X4     Y
# 0  24.5   0.0  11.2  73.4  40.3
# 1   0.0  11.2  40.3  32.2   0.0
# 2  11.2  40.3   0.0  23.8  70.4
# 3  40.3   0.0  70.4  15.2   2.2
# 4   0.0  70.4   2.2  28.9  68.2

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Y"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Y"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Y"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Y"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (940, 4)
# (940, 1)
# (404, 4)
# (404, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Y"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# defining weights and biases for the nn layers.

input_features = 4

W_1 = tf.Variable(tf.random_uniform([input_features,6])) # weights corresponding to first hidden/input layer.
b_1 = tf.Variable(tf.zeros([6]))

W_2 = tf.Variable(tf.random_uniform([6,6])) # weights corresponding to second hidden layer.
b_2 = tf.Variable(tf.zeros([6]))

W_O = tf.Variable(tf.random_uniform([6,1])) # weights corresponding to the output layer
b_O = tf.Variable(tf.zeros([1]))

# %%
def neural_net_model(X_data):
    
    # layer1 = relu(X_data.W_1 + b_1)
    layer_1 = tf.add(tf.matmul(X_data,W_1), b_1)
    layer_1 = tf.nn.relu(layer_1)
    
    # layer2 = relu(layer1.W_2 + b_2)
    layer_2 = tf.add(tf.matmul(layer_1,W_2), b_2)
    layer_2 = tf.nn.relu(layer_2)
    
    # output = layer2.W_O + b_O
    output = tf.add(tf.matmul(layer_2,W_O), b_O)
    
    return output

# %%
x_data = tf.placeholder("float")
y_target = tf.placeholder("float")

# %%
# y_predicted stores the predicted value.
y_predicted = neural_net_model(x_data)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size =  100

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the ANN regression model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,4), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.042685434
# Epoch : 1 Training Cost : 0.026442457
# Epoch : 2 Training Cost : 0.022649199
# Epoch : 3 Training Cost : 0.021978615
# Epoch : 4 Training Cost : 0.020513335
# Epoch : 5 Training Cost : 0.018748552
# Epoch : 6 Training Cost : 0.01829157
# Epoch : 7 Training Cost : 0.01707148
# Epoch : 8 Training Cost : 0.01625471
# Epoch : 9 Training Cost : 0.015878301
# Epoch : 10 Training Cost : 0.014970532
# Epoch : 11 Training Cost : 0.015696358
# Epoch : 12 Training Cost : 0.014167766
# Epoch : 13 Training Cost : 0.013705948
# Epoch : 14 Training Cost : 0.01353795
# Epoch : 15 Training Cost : 0.013026677
# Epoch : 16 Training Cost : 0.013444644
# Epoch : 17 Training Cost : 0.01347263
# Epoch : 18 Training Cost : 0.012621237
# Epoch : 19 Training Cost : 0.013661044
# Epoch : 20 Training Cost : 0.012042845
# Epoch : 21 Training Cost : 0.012125143
# Epoch : 22 Training Cost : 0.01187872
# Epoch : 23 Training Cost : 0.013627602
# Epoch : 24 Training Cost : 0.011601236
# Epoch : 25 Training Cost : 0.011558178
# Epoch : 26 Training Cost : 0.0114856595
# Epoch : 27 Training Cost : 0.011794472
# Epoch : 28 Training Cost : 0.012393162
# Epoch : 29 Training Cost : 0.011492426
# Epoch : 30 Training Cost : 0.011291451
# Epoch : 31 Training Cost : 0.012068264
# Epoch : 32 Training Cost : 0.011481272
# Epoch : 33 Training Cost : 0.011620555
# Epoch : 34 Training Cost : 0.011221162
# Epoch : 35 Training Cost : 0.01149845
# Epoch : 36 Training Cost : 0.01119703
# Epoch : 37 Training Cost : 0.01119784
# Epoch : 38 Training Cost : 0.0111951195
# Epoch : 39 Training Cost : 0.011137426
# Epoch : 40 Training Cost : 0.011406785
# Epoch : 41 Training Cost : 0.011541707
# Epoch : 42 Training Cost : 0.012662302
# Epoch : 43 Training Cost : 0.0111208735
# Epoch : 44 Training Cost : 0.011148983
# Epoch : 45 Training Cost : 0.010997913
# Epoch : 46 Training Cost : 0.011338503
# Epoch : 47 Training Cost : 0.010978054
# Epoch : 48 Training Cost : 0.011097236
# Epoch : 49 Training Cost : 0.01107291
# Epoch : 50 Training Cost : 0.011008465
# Epoch : 51 Training Cost : 0.011154792
# Epoch : 52 Training Cost : 0.010929231
# Epoch : 53 Training Cost : 0.010905009
# Epoch : 54 Training Cost : 0.014713444
# Epoch : 55 Training Cost : 0.011057936
# Epoch : 56 Training Cost : 0.010745513
# Epoch : 57 Training Cost : 0.010935939
# Epoch : 58 Training Cost : 0.010825637
# Epoch : 59 Training Cost : 0.01254045
# Epoch : 60 Training Cost : 0.011533753
# Epoch : 61 Training Cost : 0.011399273
# Epoch : 62 Training Cost : 0.011361842
# Epoch : 63 Training Cost : 0.01090411
# Epoch : 64 Training Cost : 0.012387762
# Epoch : 65 Training Cost : 0.010822328
# Epoch : 66 Training Cost : 0.010644212
# Epoch : 67 Training Cost : 0.010640523
# Epoch : 68 Training Cost : 0.010814305
# Epoch : 69 Training Cost : 0.011079981
# Epoch : 70 Training Cost : 0.010656769
# Epoch : 71 Training Cost : 0.011291994
# Epoch : 72 Training Cost : 0.010753727
# Epoch : 73 Training Cost : 0.0105995955
# Epoch : 74 Training Cost : 0.010676465
# Epoch : 75 Training Cost : 0.0113503495
# Epoch : 76 Training Cost : 0.010894356
# Epoch : 77 Training Cost : 0.01124567
# Epoch : 78 Training Cost : 0.010633844
# Epoch : 79 Training Cost : 0.011407795
# Epoch : 80 Training Cost : 0.010855756
# Epoch : 81 Training Cost : 0.010552611
# Epoch : 82 Training Cost : 0.010939256
# Epoch : 83 Training Cost : 0.010835452
# Epoch : 84 Training Cost : 0.011192659
# Epoch : 85 Training Cost : 0.010553798
# Epoch : 86 Training Cost : 0.010882287
# Epoch : 87 Training Cost : 0.011278821
# Epoch : 88 Training Cost : 0.010817234
# Epoch : 89 Training Cost : 0.0109715955
# Epoch : 90 Training Cost : 0.010635984
# Epoch : 91 Training Cost : 0.010610114
# Epoch : 92 Training Cost : 0.010496626
# Epoch : 93 Training Cost : 0.011604558
# Epoch : 94 Training Cost : 0.010553825
# Epoch : 95 Training Cost : 0.010537075
# Epoch : 96 Training Cost : 0.010546443
# Epoch : 97 Training Cost : 0.010600548
# Epoch : 98 Training Cost : 0.010564431
# Epoch : 99 Training Cost : 0.010509459
# Test Data Cost : 0.0134670455

# %%
# stores the predicted value for test data using trained ANN model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Intensity of Rainfall (in mm) ', fontsize="14")
plt.xlabel('Time (Months)', fontsize="14")
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  55.63984269576497

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  93.74325108691049

# %%
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(len(train_loss)),train_loss,label="Training loss")
plt.plot(range(len(test_loss)),test_loss,label="testing loss")
plt.legend(loc='best')
plt.ylabel('Mean Square Error (MSE)', fontsize="14")
plt.xlabel('Number of iterations', fontsize="14")
plt.show()
