# %%
import pandas as pd
import numpy as np
import random 
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from tensorflow.contrib import rnn
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("Inputset3.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
df_train.index = range(df_train.shape[0])
df_test.index = range(df_test.shape[0])

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Y"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Y"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Y"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Y"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (940, 4)
# (940, 1)
# (404, 4)
# (404, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Y"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# Reshaping the data into [samples, test_size, n_features] suitable for LSTM model.
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
#-----------------------------------------------------------------------------------------------------
# Definition for LSTM using tensorflow.

# %%
# defining hyper parameters for LSTM model.
epochs = 50
n_hidden = 50
n_features = 4
batch_size = 100
train_loss = []

# %%
# to reset tensorflow graph for every run.
tf.reset_default_graph()

# %%
# variables required for model creation.
x_data = tf.placeholder('float',[None,n_features,1])
y_target = tf.placeholder('float')

W = tf.Variable(tf.random_normal([n_hidden, 1]))
bias = tf.Variable(tf.random_normal([1]))

# 1-layer LSTM with n_hidden units.  
rnn_cell = rnn.BasicLSTMCell(n_hidden)

# %%
def rnn_model(x):

    # Generate a n_input-element sequence of inputs
    # (eg. [had] [a] [general] -> [20] [6] [33])
    x = tf.unstack(x, n_features, 1)

    # generate prediction
    outputs, states = rnn.static_rnn(rnn_cell, x, dtype=tf.float32)

    # there are n_features outputs but
    # we only want the last output
    return (tf.matmul(outputs[-1], W) + bias)

# %%
# output equation of LSTM model.
y_predicted = tf.reshape(rnn_model(x_data),[-1])

# %%
# loss function = MSE (Mean Squared Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Adam as the optimization algorithm.
optimizer = tf.train.AdamOptimizer(0.01).minimize(cost)
#tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())
sess.run(tf.local_variables_initializer())

# %%
for epoch in range(epochs):
    
        start = random.randint(0,(len(X_train)-batch_size))
        end = start + batch_size

        batch_x = np.array(X_train[start:end])
        batch_y = np.array(Y_train[start:end])
        
        # loop for training each batch.    
        for j in range(batch_x.shape[0]): 
            sess.run(optimizer, feed_dict={x_data: batch_x[j].reshape(1,4,1) , y_target: batch_y[j]})
        #loop for training each batch ends.       
            
        train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
        
        print('Epoch', epoch, 'completed out of', epochs, 'Training_loss:', train_loss[epoch])
# Out:
# Epoch 0 completed out of 50 Training_loss: 0.08192451
# Epoch 1 completed out of 50 Training_loss: 0.05305609
# Epoch 2 completed out of 50 Training_loss: 0.052047152
# Epoch 3 completed out of 50 Training_loss: 0.05326913
# Epoch 4 completed out of 50 Training_loss: 0.063909166
# Epoch 5 completed out of 50 Training_loss: 0.06567407
# Epoch 6 completed out of 50 Training_loss: 0.06780919
# Epoch 7 completed out of 50 Training_loss: 0.0691152
# Epoch 8 completed out of 50 Training_loss: 0.06393283
# Epoch 9 completed out of 50 Training_loss: 0.07846188
# Epoch 10 completed out of 50 Training_loss: 0.07921634
# Epoch 11 completed out of 50 Training_loss: 0.06414212
# Epoch 12 completed out of 50 Training_loss: 0.077555664
# Epoch 13 completed out of 50 Training_loss: 0.059808563
# Epoch 14 completed out of 50 Training_loss: 0.06352429
# Epoch 15 completed out of 50 Training_loss: 0.053540535
# Epoch 16 completed out of 50 Training_loss: 0.059418865
# Epoch 17 completed out of 50 Training_loss: 0.062596485
# Epoch 18 completed out of 50 Training_loss: 0.05879252
# Epoch 19 completed out of 50 Training_loss: 0.0638312
# Epoch 20 completed out of 50 Training_loss: 0.06843837
# Epoch 21 completed out of 50 Training_loss: 0.06386592
# Epoch 22 completed out of 50 Training_loss: 0.058982417
# Epoch 23 completed out of 50 Training_loss: 0.064244844
# Epoch 24 completed out of 50 Training_loss: 0.057112228
# Epoch 25 completed out of 50 Training_loss: 0.062812425
# Epoch 26 completed out of 50 Training_loss: 0.06470776
# Epoch 27 completed out of 50 Training_loss: 0.06972851
# Epoch 28 completed out of 50 Training_loss: 0.0645979
# Epoch 29 completed out of 50 Training_loss: 0.062752984
# Epoch 30 completed out of 50 Training_loss: 0.067767985
# Epoch 31 completed out of 50 Training_loss: 0.06981782
# Epoch 32 completed out of 50 Training_loss: 0.06496509
# Epoch 33 completed out of 50 Training_loss: 0.07360501
# Epoch 34 completed out of 50 Training_loss: 0.059199017
# Epoch 35 completed out of 50 Training_loss: 0.0712425
# Epoch 36 completed out of 50 Training_loss: 0.066635944
# Epoch 37 completed out of 50 Training_loss: 0.06026262
# Epoch 38 completed out of 50 Training_loss: 0.06348481
# Epoch 39 completed out of 50 Training_loss: 0.06262292
# Epoch 40 completed out of 50 Training_loss: 0.062719196
# Epoch 41 completed out of 50 Training_loss: 0.055052567
# Epoch 42 completed out of 50 Training_loss: 0.058473565
# Epoch 43 completed out of 50 Training_loss: 0.05394626
# Epoch 44 completed out of 50 Training_loss: 0.061697084
# Epoch 45 completed out of 50 Training_loss: 0.063589066
# Epoch 46 completed out of 50 Training_loss: 0.059068557
# Epoch 47 completed out of 50 Training_loss: 0.060848225
# Epoch 48 completed out of 50 Training_loss: 0.05906331
# Epoch 49 completed out of 50 Training_loss: 0.06657155

# %%
# stores the predicted value for test data.
pred = sess.run(y_predicted, feed_dict={x_data:X_test})

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data.
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall (in mm)', fontsize="14")
plt.xlabel('Time (Months)', fontsize="14")
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  58.49286357968456

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  94.76866019906403
