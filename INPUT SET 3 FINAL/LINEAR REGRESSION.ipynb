# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("Inputset3.xlsx")

# %%
df.head()
# Out:
#      X1    X2    X3    X4     Y
# 0  24.5   0.0  11.2  73.4  40.3
# 1   0.0  11.2  40.3  32.2   0.0
# 2  11.2  40.3   0.0  23.8  70.4
# 3  40.3   0.0  70.4  15.2   2.2
# 4   0.0  70.4   2.2  28.9  68.2

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Y"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Y"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Y"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Y"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (940, 4)
# (940, 1)
# (404, 4)
# (404, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Y"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# variables required for model creation.
x_data = tf.placeholder(shape=[None, 4], dtype=tf.float32)
y_target = tf.placeholder(shape=[None,1], dtype = tf.float32)
W = tf.Variable(tf.random_normal(shape=[4,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# %%
# output equation of linear regression model i.e. y_predicted = X_data.W + b
y_predicted = tf.add(tf.matmul(x_data, W), b)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size = 100

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the linear regression model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,4), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
    #print(sess.run(W).reshape(1,4))
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.061650578
# Epoch : 1 Training Cost : 0.041462097
# Epoch : 2 Training Cost : 0.037559595
# Epoch : 3 Training Cost : 0.03203393
# Epoch : 4 Training Cost : 0.028410329
# Epoch : 5 Training Cost : 0.024419768
# Epoch : 6 Training Cost : 0.023245588
# Epoch : 7 Training Cost : 0.02097811
# Epoch : 8 Training Cost : 0.019791147
# Epoch : 9 Training Cost : 0.01841642
# Epoch : 10 Training Cost : 0.01838836
# Epoch : 11 Training Cost : 0.01696572
# Epoch : 12 Training Cost : 0.016226815
# Epoch : 13 Training Cost : 0.015931016
# Epoch : 14 Training Cost : 0.015897697
# Epoch : 15 Training Cost : 0.016320087
# Epoch : 16 Training Cost : 0.014946253
# Epoch : 17 Training Cost : 0.014828914
# Epoch : 18 Training Cost : 0.01461245
# Epoch : 19 Training Cost : 0.0145208975
# Epoch : 20 Training Cost : 0.014266774
# Epoch : 21 Training Cost : 0.014034581
# Epoch : 22 Training Cost : 0.013898285
# Epoch : 23 Training Cost : 0.013813739
# Epoch : 24 Training Cost : 0.014732958
# Epoch : 25 Training Cost : 0.0138408765
# Epoch : 26 Training Cost : 0.013708969
# Epoch : 27 Training Cost : 0.013635157
# Epoch : 28 Training Cost : 0.013379362
# Epoch : 29 Training Cost : 0.013234518
# Epoch : 30 Training Cost : 0.013176893
# Epoch : 31 Training Cost : 0.013079724
# Epoch : 32 Training Cost : 0.013013976
# Epoch : 33 Training Cost : 0.012896177
# Epoch : 34 Training Cost : 0.01291493
# Epoch : 35 Training Cost : 0.012930941
# Epoch : 36 Training Cost : 0.012851234
# Epoch : 37 Training Cost : 0.0126865385
# Epoch : 38 Training Cost : 0.012586381
# Epoch : 39 Training Cost : 0.012546153
# Epoch : 40 Training Cost : 0.0125247575
# Epoch : 41 Training Cost : 0.012853393
# Epoch : 42 Training Cost : 0.01256132
# Epoch : 43 Training Cost : 0.013002009
# Epoch : 44 Training Cost : 0.012347778
# Epoch : 45 Training Cost : 0.012343967
# Epoch : 46 Training Cost : 0.012318204
# Epoch : 47 Training Cost : 0.012327947
# Epoch : 48 Training Cost : 0.012333582
# Epoch : 49 Training Cost : 0.012172567
# Epoch : 50 Training Cost : 0.0122013455
# Epoch : 51 Training Cost : 0.012352857
# Epoch : 52 Training Cost : 0.012843893
# Epoch : 53 Training Cost : 0.011991403
# Epoch : 54 Training Cost : 0.012016237
# Epoch : 55 Training Cost : 0.012172045
# Epoch : 56 Training Cost : 0.012076568
# Epoch : 57 Training Cost : 0.011977135
# Epoch : 58 Training Cost : 0.011960711
# Epoch : 59 Training Cost : 0.012108817
# Epoch : 60 Training Cost : 0.012011696
# Epoch : 61 Training Cost : 0.01202969
# Epoch : 62 Training Cost : 0.012082999
# Epoch : 63 Training Cost : 0.011913066
# Epoch : 64 Training Cost : 0.011850036
# Epoch : 65 Training Cost : 0.011818445
# Epoch : 66 Training Cost : 0.011805095
# Epoch : 67 Training Cost : 0.011803016
# Epoch : 68 Training Cost : 0.011775811
# Epoch : 69 Training Cost : 0.012021788
# Epoch : 70 Training Cost : 0.011729221
# Epoch : 71 Training Cost : 0.011667968
# Epoch : 72 Training Cost : 0.011586323
# Epoch : 73 Training Cost : 0.0115922
# Epoch : 74 Training Cost : 0.01159224
# Epoch : 75 Training Cost : 0.011769377
# Epoch : 76 Training Cost : 0.011588078
# Epoch : 77 Training Cost : 0.011624695
# Epoch : 78 Training Cost : 0.011573678
# Epoch : 79 Training Cost : 0.011567968
# Epoch : 80 Training Cost : 0.011503278
# Epoch : 81 Training Cost : 0.011474507
# Epoch : 82 Training Cost : 0.011489277
# Epoch : 83 Training Cost : 0.011524367
# Epoch : 84 Training Cost : 0.011620921
# Epoch : 85 Training Cost : 0.011504332
# Epoch : 86 Training Cost : 0.011445796
# Epoch : 87 Training Cost : 0.011449616
# Epoch : 88 Training Cost : 0.011415694
# Epoch : 89 Training Cost : 0.01141595
# Epoch : 90 Training Cost : 0.01236322
# Epoch : 91 Training Cost : 0.011434423
# Epoch : 92 Training Cost : 0.011391772
# Epoch : 93 Training Cost : 0.011404115
# Epoch : 94 Training Cost : 0.011643034
# Epoch : 95 Training Cost : 0.011504462
# Epoch : 96 Training Cost : 0.011362799
# Epoch : 97 Training Cost : 0.011343291
# Epoch : 98 Training Cost : 0.011391337
# Epoch : 99 Training Cost : 0.01148402
# Test Data Cost : 0.01438037

# %%
# stores the predicted value for test data using trained linear regression model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall (in mm)', fontsize="14")
plt.xlabel('Time (Months)', fontsize="14")
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  58.56749974360117

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  96.86990791459488

# %%
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(len(train_loss)),train_loss,label="Training loss")
plt.plot(range(len(test_loss)),test_loss,label="testing loss")
plt.legend(loc='best')
plt.ylabel('Mean Square Error (MSE)', fontsize="14")
plt.xlabel('Number of iterations', fontsize="14")
plt.show()
