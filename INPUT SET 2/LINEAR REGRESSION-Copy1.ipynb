# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("INPUT SET 2.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Year4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Year4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Year4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Year4"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (940, 3)
# (940, 1)
# (404, 3)
# (404, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Year4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# variables required for model creation.
x_data = tf.placeholder(shape=[None, 3], dtype=tf.float32)
y_target = tf.placeholder(shape=[None,1], dtype = tf.float32)
W = tf.Variable(tf.random_normal(shape=[3,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# %%
# output equation of linear regression model i.e. y_predicted = X_data.W + b
y_predicted = tf.add(tf.matmul(x_data, W), b)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size =  100

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the linear regression model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,3), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
    #print(sess.run(W).reshape(1,3))
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.28589508
# Epoch : 1 Training Cost : 0.22014615
# Epoch : 2 Training Cost : 0.17375515
# Epoch : 3 Training Cost : 0.121244185
# Epoch : 4 Training Cost : 0.103971496
# Epoch : 5 Training Cost : 0.08120817
# Epoch : 6 Training Cost : 0.07124531
# Epoch : 7 Training Cost : 0.061029658
# Epoch : 8 Training Cost : 0.05470877
# Epoch : 9 Training Cost : 0.04695483
# Epoch : 10 Training Cost : 0.041644502
# Epoch : 11 Training Cost : 0.038316257
# Epoch : 12 Training Cost : 0.0360633
# Epoch : 13 Training Cost : 0.03476059
# Epoch : 14 Training Cost : 0.033714294
# Epoch : 15 Training Cost : 0.03468451
# Epoch : 16 Training Cost : 0.032236785
# Epoch : 17 Training Cost : 0.030958463
# Epoch : 18 Training Cost : 0.02954931
# Epoch : 19 Training Cost : 0.028554216
# Epoch : 20 Training Cost : 0.0278234
# Epoch : 21 Training Cost : 0.028474914
# Epoch : 22 Training Cost : 0.026868548
# Epoch : 23 Training Cost : 0.026302455
# Epoch : 24 Training Cost : 0.025524035
# Epoch : 25 Training Cost : 0.025478406
# Epoch : 26 Training Cost : 0.024566906
# Epoch : 27 Training Cost : 0.024596859
# Epoch : 28 Training Cost : 0.023768356
# Epoch : 29 Training Cost : 0.02355117
# Epoch : 30 Training Cost : 0.023142682
# Epoch : 31 Training Cost : 0.022617547
# Epoch : 32 Training Cost : 0.022072028
# Epoch : 33 Training Cost : 0.022061387
# Epoch : 34 Training Cost : 0.02133987
# Epoch : 35 Training Cost : 0.020717058
# Epoch : 36 Training Cost : 0.020530952
# Epoch : 37 Training Cost : 0.020128574
# Epoch : 38 Training Cost : 0.020177482
# Epoch : 39 Training Cost : 0.019817904
# Epoch : 40 Training Cost : 0.019277437
# Epoch : 41 Training Cost : 0.019214457
# Epoch : 42 Training Cost : 0.018917052
# Epoch : 43 Training Cost : 0.018498478
# Epoch : 44 Training Cost : 0.018383114
# Epoch : 45 Training Cost : 0.018001402
# Epoch : 46 Training Cost : 0.017677238
# Epoch : 47 Training Cost : 0.017618861
# Epoch : 48 Training Cost : 0.017481666
# Epoch : 49 Training Cost : 0.017512627
# Epoch : 50 Training Cost : 0.017725136
# Epoch : 51 Training Cost : 0.016925104
# Epoch : 52 Training Cost : 0.016875101
# Epoch : 53 Training Cost : 0.016473
# Epoch : 54 Training Cost : 0.017016662
# Epoch : 55 Training Cost : 0.016197447
# Epoch : 56 Training Cost : 0.016116498
# Epoch : 57 Training Cost : 0.015671667
# Epoch : 58 Training Cost : 0.015519689
# Epoch : 59 Training Cost : 0.015537304
# Epoch : 60 Training Cost : 0.01520032
# Epoch : 61 Training Cost : 0.0150029855
# Epoch : 62 Training Cost : 0.014885037
# Epoch : 63 Training Cost : 0.01483247
# Epoch : 64 Training Cost : 0.014753471
# Epoch : 65 Training Cost : 0.014729565
# Epoch : 66 Training Cost : 0.014536815
# Epoch : 67 Training Cost : 0.015229729
# Epoch : 68 Training Cost : 0.014318164
# Epoch : 69 Training Cost : 0.0142693315
# Epoch : 70 Training Cost : 0.014184761
# Epoch : 71 Training Cost : 0.01408501
# Epoch : 72 Training Cost : 0.014053727
# Epoch : 73 Training Cost : 0.0142231705
# Epoch : 74 Training Cost : 0.014276447
# Epoch : 75 Training Cost : 0.013817378
# Epoch : 76 Training Cost : 0.013770497
# Epoch : 77 Training Cost : 0.013655264
# Epoch : 78 Training Cost : 0.013511214
# Epoch : 79 Training Cost : 0.013443278
# Epoch : 80 Training Cost : 0.013374519
# Epoch : 81 Training Cost : 0.013634385
# Epoch : 82 Training Cost : 0.013299634
# Epoch : 83 Training Cost : 0.013387192
# Epoch : 84 Training Cost : 0.013158365
# Epoch : 85 Training Cost : 0.01321983
# Epoch : 86 Training Cost : 0.013010338
# Epoch : 87 Training Cost : 0.012936525
# Epoch : 88 Training Cost : 0.012853386
# Epoch : 89 Training Cost : 0.012758996
# Epoch : 90 Training Cost : 0.0129939355
# Epoch : 91 Training Cost : 0.012717861
# Epoch : 92 Training Cost : 0.012649142
# Epoch : 93 Training Cost : 0.013013817
# Epoch : 94 Training Cost : 0.012545245
# Epoch : 95 Training Cost : 0.012512864
# Epoch : 96 Training Cost : 0.01261548
# Epoch : 97 Training Cost : 0.012718251
# Epoch : 98 Training Cost : 0.012990066
# Epoch : 99 Training Cost : 0.012356079
# Test Data Cost : 0.015557577

# %%
# stores the predicted value for test data using trained linear regression model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall (in mm)', fontsize="14")
plt.xlabel('Time(Months)', fontsize="14")
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  63.15734824378891

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  101.45438306703713

# %%
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(len(train_loss)),train_loss,label="Training loss")
plt.plot(range(len(test_loss)),test_loss,label="testing loss")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall (in mm)', fontsize="14")
plt.xlabel('Time (Months)', fontsize="14")
plt.show()
