# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("INPUT SET 2.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.4, shuffle = True)

# %%
df_train.index = range(df_train.shape[0])
df_test.index = range(df_test.shape[0])

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Year4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Year4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Year4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Year4"].values.reshape(-1,1))

# %%
# function to denormalize the obtained output.
def denormalize(df,norm_data):
    df = df["Year4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
#-----------------------------------------------------------------------------------------------------
# SVR using kernel definition.

# %%
# defining variables and parameters used for model definition and training.
batch_size = 50
epochs = 100
x_data = tf.placeholder(shape=[None, 3], dtype=tf.float32)
y_target = tf.placeholder(shape=[None, 1], dtype=tf.float32)
prediction_data = tf.placeholder(shape=[None, 3], dtype=tf.float32)
b = tf.Variable(tf.zeros(shape=[1,batch_size]))

# %%
indices = np.random.choice(len(X_train), batch_size)

# %%
# kernel definition.(linear, polynomial, RBF)

def kernel(kernel_name):
    if(kernel_name == "rbf"):
        gamma = tf.constant(-1.)
        # rA = X_data^2 having shape = [batch_size,1]
        rA = tf.reshape(tf.reduce_sum(tf.square(x_data), 1),[-1,1]) 
        # rB = prediction_data^2 having shape = [prediction_sample,1]
        rB = tf.reshape(tf.reduce_sum(tf.square(prediction_data), 1),[-1,1])
        # pred_sq_list gives the square distance between prediction_data and every other X_data's samples.
        # pred_sq_list = X^2 - 2.X.Xi + Xi^2
        pred_sq_dist = tf.add(tf.subtract(rA, tf.multiply(2., tf.matmul(x_data,tf.transpose(prediction_data)))), tf.transpose(rB))
        #pred_kernel = exp(-gamma*(||X-Xi||**2))
        pred_kernel = tf.exp(tf.multiply(gamma, tf.abs(pred_sq_dist))) 
        
    elif(kernel_name == "poly"):
        degree = tf.constant(2.0)
        # pred_kernel = (1+X.Xi)**2
        pred_kernel = (tf.add(1.0, tf.matmul(x_data,tf.transpose(prediction_data))))**degree
        
    else:
        #pred_kernel = X.Xi
        pred_kernel = tf.matmul(x_data,tf.transpose(prediction_data))
        
    return pred_kernel

# %%
my_kernel = kernel("linear")

# %%
# output hyperplane 
y_predicted = tf.matmul(b, my_kernel)

# %%
# definition for the loss function.
epsilon = tf.constant([0.08])
# b_vec_cross = bi.bj having shape [batch_size, batch_size]
b_vec_cross = tf.matmul(tf.transpose(b),b)
#first_term = summation of 1/2*bi.bj*k(xi,xj)
first_term = tf.reduce_sum(tf.multiply(0.5,tf.multiply(b_vec_cross, my_kernel)))
# second_term = summation of |bi|*epsilon
second_term = tf.multiply(epsilon,tf.reduce_sum(tf.abs(b)))
# third_term = summation of bi.yi
third_term = tf.matmul(b, y_target)
#loss = first_term + second_term - third_term
loss = tf.subtract(tf.add(first_term, second_term), third_term)

# %%
train = tf.train.GradientDescentOptimizer(0.01).minimize(loss)

# %%
train_loss = []
test_loss = []

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# loop for training SVR model.

for i in range(epochs):
        
    train_indices = np.random.choice(len(X_train), batch_size)
    x_train = X_train[train_indices]
    y_train = Y_train[train_indices]
    test_indices = np.random.choice(len(X_test), batch_size)
    x_test = X_test[test_indices]
    y_test = Y_test[test_indices]
    
    for j in range(x_train.shape[0]):
        sess.run(train,feed_dict={x_data:x_train, y_target:y_train, prediction_data:x_train[j,:].reshape(1,3)})
    
    train_loss.append(sess.run(loss,feed_dict={x_data:x_train, y_target:y_train, prediction_data:x_train}))
    test_loss.append(sess.run(loss, feed_dict={x_data:x_test, y_target:y_test, prediction_data:x_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
        
# end of for loop for training the model.
# Out:
# Epoch : 0 Training Cost : [[-0.1182133]]
# Epoch : 1 Training Cost : [[-0.26836002]]
# Epoch : 2 Training Cost : [[-0.15278935]]
# Epoch : 3 Training Cost : [[-0.03360242]]
# Epoch : 4 Training Cost : [[-0.16057897]]
# Epoch : 5 Training Cost : [[-0.06522131]]
# Epoch : 6 Training Cost : [[-0.03318855]]
# Epoch : 7 Training Cost : [[-0.11616984]]
# Epoch : 8 Training Cost : [[-0.07742918]]
# Epoch : 9 Training Cost : [[0.17594641]]
# Epoch : 10 Training Cost : [[-0.2739135]]
# Epoch : 11 Training Cost : [[-0.08270526]]
# Epoch : 12 Training Cost : [[-0.05437818]]
# Epoch : 13 Training Cost : [[-0.23270094]]
# Epoch : 14 Training Cost : [[-0.12500614]]
# Epoch : 15 Training Cost : [[-0.06376132]]
# Epoch : 16 Training Cost : [[-0.13674495]]
# Epoch : 17 Training Cost : [[-0.12919295]]
# Epoch : 18 Training Cost : [[-0.07258964]]
# Epoch : 19 Training Cost : [[-0.05002549]]
# Epoch : 20 Training Cost : [[-0.25357756]]
# Epoch : 21 Training Cost : [[0.00515005]]
# Epoch : 22 Training Cost : [[-0.05824244]]
# Epoch : 23 Training Cost : [[0.00731266]]
# Epoch : 24 Training Cost : [[-0.11599219]]
# Epoch : 25 Training Cost : [[0.01811874]]
# Epoch : 26 Training Cost : [[-0.03567779]]
# Epoch : 27 Training Cost : [[-0.11849499]]
# Epoch : 28 Training Cost : [[0.07345384]]
# Epoch : 29 Training Cost : [[-0.31339526]]
# Epoch : 30 Training Cost : [[-0.08290404]]
# Epoch : 31 Training Cost : [[0.01406407]]
# Epoch : 32 Training Cost : [[-0.06940639]]
# Epoch : 33 Training Cost : [[-0.25761813]]
# Epoch : 34 Training Cost : [[-0.07272995]]
# Epoch : 35 Training Cost : [[-0.05838051]]
# Epoch : 36 Training Cost : [[0.20888242]]
# Epoch : 37 Training Cost : [[-0.05409437]]
# Epoch : 38 Training Cost : [[-0.07337445]]
# Epoch : 39 Training Cost : [[-0.19499052]]
# Epoch : 40 Training Cost : [[-0.05050611]]
# Epoch : 41 Training Cost : [[-0.11895251]]
# Epoch : 42 Training Cost : [[-0.0265145]]
# Epoch : 43 Training Cost : [[-0.19406092]]
# Epoch : 44 Training Cost : [[-0.17260623]]
# Epoch : 45 Training Cost : [[-0.07518721]]
# Epoch : 46 Training Cost : [[0.0879114]]
# Epoch : 47 Training Cost : [[-0.18308353]]
# Epoch : 48 Training Cost : [[-0.07000318]]
# Epoch : 49 Training Cost : [[-0.26157463]]
# Epoch : 50 Training Cost : [[-0.00946659]]
# Epoch : 51 Training Cost : [[-0.18959224]]
# Epoch : 52 Training Cost : [[-0.01706186]]
# Epoch : 53 Training Cost : [[-0.13929373]]
# Epoch : 54 Training Cost : [[-0.02942288]]
# Epoch : 55 Training Cost : [[-0.0838604]]
# Epoch : 56 Training Cost : [[-0.09644693]]
# Epoch : 57 Training Cost : [[-0.04421842]]
# Epoch : 58 Training Cost : [[-0.05688709]]
# Epoch : 59 Training Cost : [[-0.08645409]]
# Epoch : 60 Training Cost : [[-0.22130221]]
# Epoch : 61 Training Cost : [[-0.08436203]]
# Epoch : 62 Training Cost : [[-0.25953567]]
# Epoch : 63 Training Cost : [[-0.01092705]]
# Epoch : 64 Training Cost : [[0.04868037]]
# Epoch : 65 Training Cost : [[0.02812746]]
# Epoch : 66 Training Cost : [[-0.06925929]]
# Epoch : 67 Training Cost : [[-0.10102701]]
# Epoch : 68 Training Cost : [[-0.04785943]]
# Epoch : 69 Training Cost : [[0.00788897]]
# Epoch : 70 Training Cost : [[0.006612]]
# Epoch : 71 Training Cost : [[-0.09992334]]
# Epoch : 72 Training Cost : [[-0.13359356]]
# Epoch : 73 Training Cost : [[-0.10829988]]
# Epoch : 74 Training Cost : [[-0.05490249]]
# Epoch : 75 Training Cost : [[-0.1221686]]
# Epoch : 76 Training Cost : [[0.00167885]]
# Epoch : 77 Training Cost : [[-0.03375912]]
# Epoch : 78 Training Cost : [[-0.32085967]]
# Epoch : 79 Training Cost : [[-0.12825465]]
# Epoch : 80 Training Cost : [[-0.03565103]]
# Epoch : 81 Training Cost : [[-0.11525667]]
# Epoch : 82 Training Cost : [[0.00477201]]
# Epoch : 83 Training Cost : [[-0.00347388]]
# Epoch : 84 Training Cost : [[-0.03417826]]
# Epoch : 85 Training Cost : [[-0.07873484]]
# Epoch : 86 Training Cost : [[-0.19577518]]
# Epoch : 87 Training Cost : [[-0.12334424]]
# Epoch : 88 Training Cost : [[-0.13075179]]
# Epoch : 89 Training Cost : [[-0.28010243]]
# Epoch : 90 Training Cost : [[-0.00610119]]
# Epoch : 91 Training Cost : [[-0.12400323]]
# Epoch : 92 Training Cost : [[-0.06686705]]
# Epoch : 93 Training Cost : [[-0.04062384]]
# Epoch : 94 Training Cost : [[-0.12964463]]
# Epoch : 95 Training Cost : [[-0.1650894]]
# Epoch : 96 Training Cost : [[-0.03371888]]
# Epoch : 97 Training Cost : [[-0.16321376]]
# Epoch : 98 Training Cost : [[-0.08591461]]
# Epoch : 99 Training Cost : [[-0.10570002]]

# %%
x = X_train[indices]
# predicting ouput for X_test.
pred = sess.run(y_predicted, feed_dict={x_data:x, prediction_data:X_test})

# %%
# denormalizing Y_test and corresponding predicted output.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data.
plt.figure(figsize=[20,8])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Output of SVR (using linear kernel) ')
plt.show()

# %%
# Mean absolute Error.
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  83.8932212283357

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  151.90355303018816
