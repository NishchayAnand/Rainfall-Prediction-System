# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("INPUT SET 2.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
df_train.index = range(df_train.shape[0])
df_test.index = range(df_test.shape[0])

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Year4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Year4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Year4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Year4"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (940, 3)
# (940, 1)
# (404, 3)
# (404, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Year4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# definition for svr model (primal problem using linear kernel) using tensorflow.

# %%
# variables required for model creation.
x_data = tf.placeholder(shape=[None, 3], dtype=tf.float32)
y_target = tf.placeholder(shape=[None,1], dtype = tf.float32)
W = tf.Variable(tf.random_normal(shape=[3,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# %%
# output equation of linear regression model i.e. y_predicted = X_data.W + b
y_predicted = tf.add(tf.matmul(x_data, W), b)

# %%
# loss function = mean(max(0, |y_predicted-y_target|-E))
epsilon = tf.constant([0.01])
cost = tf.reduce_mean(tf.maximum(0., tf.subtract(tf.abs(tf.subtract(y_predicted, y_target)), epsilon)))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0229 15:40:00.606508 15160 deprecation.py:323] From c:\users\win10\appdata\local\programs\python\python37\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
train_loss = []
test_loss = [] 
batch_size = 200

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the SVR primal model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,3), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
    #print(sess.run(W).reshape(1,3))
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.15964256
# Epoch : 1 Training Cost : 0.107915476
# Epoch : 2 Training Cost : 0.0697173
# Epoch : 3 Training Cost : 0.059449982
# Epoch : 4 Training Cost : 0.059181567
# Epoch : 5 Training Cost : 0.058911804
# Epoch : 6 Training Cost : 0.056933552
# Epoch : 7 Training Cost : 0.056552146
# Epoch : 8 Training Cost : 0.05652558
# Epoch : 9 Training Cost : 0.056882754
# Epoch : 10 Training Cost : 0.056610417
# Epoch : 11 Training Cost : 0.057649698
# Epoch : 12 Training Cost : 0.055630874
# Epoch : 13 Training Cost : 0.06121612
# Epoch : 14 Training Cost : 0.05610971
# Epoch : 15 Training Cost : 0.056828532
# Epoch : 16 Training Cost : 0.055798985
# Epoch : 17 Training Cost : 0.05536208
# Epoch : 18 Training Cost : 0.05886145
# Epoch : 19 Training Cost : 0.061015237
# Epoch : 20 Training Cost : 0.06194186
# Epoch : 21 Training Cost : 0.058912862
# Epoch : 22 Training Cost : 0.07383483
# Epoch : 23 Training Cost : 0.062137637
# Epoch : 24 Training Cost : 0.055329543
# Epoch : 25 Training Cost : 0.057526316
# Epoch : 26 Training Cost : 0.055575553
# Epoch : 27 Training Cost : 0.055324014
# Epoch : 28 Training Cost : 0.05552639
# Epoch : 29 Training Cost : 0.063374214
# Epoch : 30 Training Cost : 0.055641573
# Epoch : 31 Training Cost : 0.057546355
# Epoch : 32 Training Cost : 0.055322547
# Epoch : 33 Training Cost : 0.055304974
# Epoch : 34 Training Cost : 0.056719884
# Epoch : 35 Training Cost : 0.0555775
# Epoch : 36 Training Cost : 0.05531508
# Epoch : 37 Training Cost : 0.056086205
# Epoch : 38 Training Cost : 0.05564579
# Epoch : 39 Training Cost : 0.05560945
# Epoch : 40 Training Cost : 0.05572884
# Epoch : 41 Training Cost : 0.055695876
# Epoch : 42 Training Cost : 0.055352256
# Epoch : 43 Training Cost : 0.057934236
# Epoch : 44 Training Cost : 0.057490468
# Epoch : 45 Training Cost : 0.05556088
# Epoch : 46 Training Cost : 0.057118036
# Epoch : 47 Training Cost : 0.05534034
# Epoch : 48 Training Cost : 0.0552692
# Epoch : 49 Training Cost : 0.05820479
# Epoch : 50 Training Cost : 0.05528944
# Epoch : 51 Training Cost : 0.057668705
# Epoch : 52 Training Cost : 0.060682163
# Epoch : 53 Training Cost : 0.057712764
# Epoch : 54 Training Cost : 0.059979036
# Epoch : 55 Training Cost : 0.0556531
# Epoch : 56 Training Cost : 0.058527183
# Epoch : 57 Training Cost : 0.056910034
# Epoch : 58 Training Cost : 0.055325978
# Epoch : 59 Training Cost : 0.05998762
# Epoch : 60 Training Cost : 0.055286303
# Epoch : 61 Training Cost : 0.05532132
# Epoch : 62 Training Cost : 0.0556504
# Epoch : 63 Training Cost : 0.05720226
# Epoch : 64 Training Cost : 0.058119684
# Epoch : 65 Training Cost : 0.067704745
# Epoch : 66 Training Cost : 0.05574663
# Epoch : 67 Training Cost : 0.056980547
# Epoch : 68 Training Cost : 0.05742793
# Epoch : 69 Training Cost : 0.055276405
# Epoch : 70 Training Cost : 0.060249824
# Epoch : 71 Training Cost : 0.056606956
# Epoch : 72 Training Cost : 0.05889986
# Epoch : 73 Training Cost : 0.05661289
# Epoch : 74 Training Cost : 0.0583129
# Epoch : 75 Training Cost : 0.06100986
# Epoch : 76 Training Cost : 0.055303145
# Epoch : 77 Training Cost : 0.055401586
# Epoch : 78 Training Cost : 0.056689158
# Epoch : 79 Training Cost : 0.06057208
# Epoch : 80 Training Cost : 0.05563864
# Epoch : 81 Training Cost : 0.05748757
# Epoch : 82 Training Cost : 0.05579397
# Epoch : 83 Training Cost : 0.05538025
# Epoch : 84 Training Cost : 0.05555142
# Epoch : 85 Training Cost : 0.05773414
# Epoch : 86 Training Cost : 0.05795466
# Epoch : 87 Training Cost : 0.05807447
# Epoch : 88 Training Cost : 0.055576444
# Epoch : 89 Training Cost : 0.0556922
# Epoch : 90 Training Cost : 0.056070004
# Epoch : 91 Training Cost : 0.055350028
# Epoch : 92 Training Cost : 0.058925193
# Epoch : 93 Training Cost : 0.055305388
# Epoch : 94 Training Cost : 0.057470158
# Epoch : 95 Training Cost : 0.057383247
# Epoch : 96 Training Cost : 0.05558351
# Epoch : 97 Training Cost : 0.05601759
# Epoch : 98 Training Cost : 0.05844602
# Epoch : 99 Training Cost : 0.056746043
# Test Data Cost : 0.06272378

# %%
# stores the predicted value for test data using trained SVR model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data.
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall (in mm)', fontsize="14")
plt.xlabel('Time (Months)', fontsize="14")
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  58.0873666243351

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  100.10488673658848
