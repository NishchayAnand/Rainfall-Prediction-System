# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("C:/Users/win10/Desktop/Consecutive_year_monthly_rainfall_intensity.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.4, shuffle = True)

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Year4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Year4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Year4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Year4"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (806, 3)
# (806, 1)
# (538, 3)
# (538, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Year4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# defining weights and biases for the nn layers.

input_features = 3

W_1 = tf.Variable(tf.random_uniform([input_features,6])) # weights corresponding to first hidden/input layer.
b_1 = tf.Variable(tf.zeros([6]))

W_2 = tf.Variable(tf.random_uniform([6,6])) # weights corresponding to second hidden layer.
b_2 = tf.Variable(tf.zeros([6]))

W_O = tf.Variable(tf.random_uniform([6,1])) # weights corresponding to the output layer
b_O = tf.Variable(tf.zeros([1]))

# %%
def neural_net_model(X_data):
    
    # layer1 = relu(X_data.W_1 + b_1)
    layer_1 = tf.add(tf.matmul(X_data,W_1), b_1)
    layer_1 = tf.nn.relu(layer_1)
    
    # layer2 = relu(layer1.W_2 + b_2)
    layer_2 = tf.add(tf.matmul(layer_1,W_2), b_2)
    layer_2 = tf.nn.relu(layer_2)
    
    # output = layer2.W_O + b_O
    output = tf.add(tf.matmul(layer_2,W_O), b_O)
    
    return output

# %%
x_data = tf.placeholder("float")
y_target = tf.placeholder("float")

# %%
# y_predicted stores the predicted value.
y_predicted = neural_net_model(x_data)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size =  100

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the ANN regression model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,3), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.045626406
# Epoch : 1 Training Cost : 0.03215997
# Epoch : 2 Training Cost : 0.03118536
# Epoch : 3 Training Cost : 0.030027907
# Epoch : 4 Training Cost : 0.029049994
# Epoch : 5 Training Cost : 0.028135218
# Epoch : 6 Training Cost : 0.026571082
# Epoch : 7 Training Cost : 0.023590038
# Epoch : 8 Training Cost : 0.02207999
# Epoch : 9 Training Cost : 0.020920474
# Epoch : 10 Training Cost : 0.020488782
# Epoch : 11 Training Cost : 0.02025055
# Epoch : 12 Training Cost : 0.018973252
# Epoch : 13 Training Cost : 0.01851376
# Epoch : 14 Training Cost : 0.018587984
# Epoch : 15 Training Cost : 0.017562622
# Epoch : 16 Training Cost : 0.01744068
# Epoch : 17 Training Cost : 0.017179811
# Epoch : 18 Training Cost : 0.01781307
# Epoch : 19 Training Cost : 0.016692355
# Epoch : 20 Training Cost : 0.01662678
# Epoch : 21 Training Cost : 0.016671598
# Epoch : 22 Training Cost : 0.016655857
# Epoch : 23 Training Cost : 0.01623653
# Epoch : 24 Training Cost : 0.016626256
# Epoch : 25 Training Cost : 0.016258327
# Epoch : 26 Training Cost : 0.016928107
# Epoch : 27 Training Cost : 0.017433409
# Epoch : 28 Training Cost : 0.01644986
# Epoch : 29 Training Cost : 0.016515877
# Epoch : 30 Training Cost : 0.016747555
# Epoch : 31 Training Cost : 0.015882166
# Epoch : 32 Training Cost : 0.015990052
# Epoch : 33 Training Cost : 0.015876025
# Epoch : 34 Training Cost : 0.016037524
# Epoch : 35 Training Cost : 0.015784992
# Epoch : 36 Training Cost : 0.015752284
# Epoch : 37 Training Cost : 0.016540496
# Epoch : 38 Training Cost : 0.016307293
# Epoch : 39 Training Cost : 0.015977787
# Epoch : 40 Training Cost : 0.016312543
# Epoch : 41 Training Cost : 0.015490873
# Epoch : 42 Training Cost : 0.015720619
# Epoch : 43 Training Cost : 0.01548743
# Epoch : 44 Training Cost : 0.015484851
# Epoch : 45 Training Cost : 0.015317767
# Epoch : 46 Training Cost : 0.015285361
# Epoch : 47 Training Cost : 0.0154409455
# Epoch : 48 Training Cost : 0.015214427
# Epoch : 49 Training Cost : 0.015996978
# Epoch : 50 Training Cost : 0.015061944
# Epoch : 51 Training Cost : 0.015374731
# Epoch : 52 Training Cost : 0.015535579
# Epoch : 53 Training Cost : 0.015773984
# Epoch : 54 Training Cost : 0.015687069
# Epoch : 55 Training Cost : 0.016387543
# Epoch : 56 Training Cost : 0.015551973
# Epoch : 57 Training Cost : 0.014960652
# Epoch : 58 Training Cost : 0.01618987
# Epoch : 59 Training Cost : 0.015361838
# Epoch : 60 Training Cost : 0.015765075
# Epoch : 61 Training Cost : 0.015254577
# Epoch : 62 Training Cost : 0.01489176
# Epoch : 63 Training Cost : 0.014948275
# Epoch : 64 Training Cost : 0.014961839
# Epoch : 65 Training Cost : 0.018703349
# Epoch : 66 Training Cost : 0.015309258
# Epoch : 67 Training Cost : 0.014920367
# Epoch : 68 Training Cost : 0.014860994
# Epoch : 69 Training Cost : 0.015585598
# Epoch : 70 Training Cost : 0.015181884
# Epoch : 71 Training Cost : 0.014826321
# Epoch : 72 Training Cost : 0.015308885
# Epoch : 73 Training Cost : 0.014943804
# Epoch : 74 Training Cost : 0.015245389
# Epoch : 75 Training Cost : 0.015486403
# Epoch : 76 Training Cost : 0.014862282
# Epoch : 77 Training Cost : 0.014770455
# Epoch : 78 Training Cost : 0.014729859
# Epoch : 79 Training Cost : 0.0147127835
# Epoch : 80 Training Cost : 0.016068747
# Epoch : 81 Training Cost : 0.014769864
# Epoch : 82 Training Cost : 0.014743552
# Epoch : 83 Training Cost : 0.015284273
# Epoch : 84 Training Cost : 0.0146616325
# Epoch : 85 Training Cost : 0.01495028
# Epoch : 86 Training Cost : 0.015200048
# Epoch : 87 Training Cost : 0.015873622
# Epoch : 88 Training Cost : 0.015614994
# Epoch : 89 Training Cost : 0.014939736
# Epoch : 90 Training Cost : 0.014909324
# Epoch : 91 Training Cost : 0.014963251
# Epoch : 92 Training Cost : 0.014649036
# Epoch : 93 Training Cost : 0.014924978
# Epoch : 94 Training Cost : 0.014800291
# Epoch : 95 Training Cost : 0.0147375455
# Epoch : 96 Training Cost : 0.015052084
# Epoch : 97 Training Cost : 0.014766679
# Epoch : 98 Training Cost : 0.014650318
# Epoch : 99 Training Cost : 0.015083798
# Test Data Cost : 0.015599155

# %%
# stores the predicted value for test data using trained ANN model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[20,8])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Amount of Rainfall ')
plt.show()

# %%
# plot showing difference between actual test data and predicted test data for first 100 samples.
plt.figure(figsize=[20,8])
plt.plot(range(100),y_test[:100],label="Original Data")
plt.plot(range(100),pred[:100],label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Amount of Rainfall ')
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  79.40252989729984

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  132.65265944969065
