# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("INPUT SET 2.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Year4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Year4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Year4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Year4"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (940, 3)
# (940, 1)
# (404, 3)
# (404, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Year4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# variables required for model creation.
x_data = tf.placeholder(shape=[None, 3], dtype=tf.float32)
y_target = tf.placeholder(shape=[None,1], dtype = tf.float32)
W = tf.Variable(tf.random_normal(shape=[3,1]))
b = tf.Variable(tf.random_normal(shape=[1,1]))

# %%
# output equation of linear regression model i.e. y_predicted = X_data.W + b
y_predicted = tf.add(tf.matmul(x_data, W), b)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size =  100

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the linear regression model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,3), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
    #print(sess.run(W).reshape(1,3))
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.16508362
# Epoch : 1 Training Cost : 0.11885997
# Epoch : 2 Training Cost : 0.08833012
# Epoch : 3 Training Cost : 0.07101117
# Epoch : 4 Training Cost : 0.060843617
# Epoch : 5 Training Cost : 0.056636184
# Epoch : 6 Training Cost : 0.04391405
# Epoch : 7 Training Cost : 0.037041638
# Epoch : 8 Training Cost : 0.03286812
# Epoch : 9 Training Cost : 0.029528314
# Epoch : 10 Training Cost : 0.026745224
# Epoch : 11 Training Cost : 0.024804292
# Epoch : 12 Training Cost : 0.024858056
# Epoch : 13 Training Cost : 0.023001177
# Epoch : 14 Training Cost : 0.021983545
# Epoch : 15 Training Cost : 0.022059938
# Epoch : 16 Training Cost : 0.021304145
# Epoch : 17 Training Cost : 0.020998958
# Epoch : 18 Training Cost : 0.020940868
# Epoch : 19 Training Cost : 0.020013867
# Epoch : 20 Training Cost : 0.019700496
# Epoch : 21 Training Cost : 0.019500796
# Epoch : 22 Training Cost : 0.019533
# Epoch : 23 Training Cost : 0.018910427
# Epoch : 24 Training Cost : 0.019285189
# Epoch : 25 Training Cost : 0.018620532
# Epoch : 26 Training Cost : 0.018217709
# Epoch : 27 Training Cost : 0.018018471
# Epoch : 28 Training Cost : 0.017669382
# Epoch : 29 Training Cost : 0.017438956
# Epoch : 30 Training Cost : 0.01714813
# Epoch : 31 Training Cost : 0.016577184
# Epoch : 32 Training Cost : 0.016363608
# Epoch : 33 Training Cost : 0.01638114
# Epoch : 34 Training Cost : 0.016043803
# Epoch : 35 Training Cost : 0.016002106
# Epoch : 36 Training Cost : 0.016012717
# Epoch : 37 Training Cost : 0.01571625
# Epoch : 38 Training Cost : 0.0154453665
# Epoch : 39 Training Cost : 0.015562392
# Epoch : 40 Training Cost : 0.015139965
# Epoch : 41 Training Cost : 0.014974897
# Epoch : 42 Training Cost : 0.015114967
# Epoch : 43 Training Cost : 0.015117641
# Epoch : 44 Training Cost : 0.014640743
# Epoch : 45 Training Cost : 0.014760155
# Epoch : 46 Training Cost : 0.014592133
# Epoch : 47 Training Cost : 0.01439412
# Epoch : 48 Training Cost : 0.014279126
# Epoch : 49 Training Cost : 0.01409776
# Epoch : 50 Training Cost : 0.014154933
# Epoch : 51 Training Cost : 0.014270566
# Epoch : 52 Training Cost : 0.014024783
# Epoch : 53 Training Cost : 0.013814051
# Epoch : 54 Training Cost : 0.013743363
# Epoch : 55 Training Cost : 0.0142128365
# Epoch : 56 Training Cost : 0.014453391
# Epoch : 57 Training Cost : 0.01416113
# Epoch : 58 Training Cost : 0.01344699
# Epoch : 59 Training Cost : 0.013366928
# Epoch : 60 Training Cost : 0.013349665
# Epoch : 61 Training Cost : 0.013314702
# Epoch : 62 Training Cost : 0.013252936
# Epoch : 63 Training Cost : 0.013186055
# Epoch : 64 Training Cost : 0.013210992
# Epoch : 65 Training Cost : 0.013092086
# Epoch : 66 Training Cost : 0.013097046
# Epoch : 67 Training Cost : 0.013028249
# Epoch : 68 Training Cost : 0.013081218
# Epoch : 69 Training Cost : 0.012880952
# Epoch : 70 Training Cost : 0.012947511
# Epoch : 71 Training Cost : 0.012803275
# Epoch : 72 Training Cost : 0.012858157
# Epoch : 73 Training Cost : 0.012731033
# Epoch : 74 Training Cost : 0.012859944
# Epoch : 75 Training Cost : 0.01299605
# Epoch : 76 Training Cost : 0.012595371
# Epoch : 77 Training Cost : 0.012545192
# Epoch : 78 Training Cost : 0.0125401
# Epoch : 79 Training Cost : 0.012724742
# Epoch : 80 Training Cost : 0.012492962
# Epoch : 81 Training Cost : 0.0127639435
# Epoch : 82 Training Cost : 0.01241656
# Epoch : 83 Training Cost : 0.012431631
# Epoch : 84 Training Cost : 0.012299685
# Epoch : 85 Training Cost : 0.012402682
# Epoch : 86 Training Cost : 0.012767048
# Epoch : 87 Training Cost : 0.012307473
# Epoch : 88 Training Cost : 0.012310377
# Epoch : 89 Training Cost : 0.012184484
# Epoch : 90 Training Cost : 0.012442149
# Epoch : 91 Training Cost : 0.012906454
# Epoch : 92 Training Cost : 0.01220398
# Epoch : 93 Training Cost : 0.012241822
# Epoch : 94 Training Cost : 0.012271695
# Epoch : 95 Training Cost : 0.012477953
# Epoch : 96 Training Cost : 0.01204333
# Epoch : 97 Training Cost : 0.011939661
# Epoch : 98 Training Cost : 0.012776059
# Epoch : 99 Training Cost : 0.012125773
# Test Data Cost : 0.015773714

# %%
# stores the predicted value for test data using trained linear regression model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  63.15734824378891

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  101.45438306703713

# %%
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(len(train_loss)),train_loss,label="Training loss")
plt.plot(range(len(test_loss)),test_loss,label="testing loss")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall (in mm)', fontsize="14")
plt.xlabel('Time (Months)', fontsize="14")
plt.show()
