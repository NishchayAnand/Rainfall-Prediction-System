# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("INPUT SET 2.xlsx")

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Year4"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Year4"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Year4"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Year4"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (940, 3)
# (940, 1)
# (404, 3)
# (404, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Year4"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# defining weights and biases for the nn layers.

input_features = 3

W_1 = tf.Variable(tf.random_uniform([input_features,4])) # weights corresponding to first hidden/input layer.
b_1 = tf.Variable(tf.zeros([4]))

W_2 = tf.Variable(tf.random_uniform([4,4])) # weights corresponding to second hidden layer.
b_2 = tf.Variable(tf.zeros([4]))

W_O = tf.Variable(tf.random_uniform([4,1])) # weights corresponding to the output layer
b_O = tf.Variable(tf.zeros([1]))

# %%
def neural_net_model(X_data):
    
    # layer1 = relu(X_data.W_1 + b_1)
    layer_1 = tf.add(tf.matmul(X_data,W_1), b_1)
    layer_1 = tf.nn.relu(layer_1)
    
    # layer2 = relu(layer1.W_2 + b_2)
    layer_2 = tf.add(tf.matmul(layer_1,W_2), b_2)
    layer_2 = tf.nn.relu(layer_2)
    
    # output = layer2.W_O + b_O
    output = tf.add(tf.matmul(layer_2,W_O), b_O)
    
    return output

# %%
x_data = tf.placeholder("float")
y_target = tf.placeholder("float")

# %%
# y_predicted stores the predicted value.
y_predicted = neural_net_model(x_data)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size =  300

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the ANN regression model.

for i in range(60):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,3), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.023835776
# Epoch : 1 Training Cost : 0.022448411
# Epoch : 2 Training Cost : 0.024187267
# Epoch : 3 Training Cost : 0.019798277
# Epoch : 4 Training Cost : 0.017135724
# Epoch : 5 Training Cost : 0.01586517
# Epoch : 6 Training Cost : 0.014819544
# Epoch : 7 Training Cost : 0.014124417
# Epoch : 8 Training Cost : 0.013196881
# Epoch : 9 Training Cost : 0.012607493
# Epoch : 10 Training Cost : 0.012122288
# Epoch : 11 Training Cost : 0.011842717
# Epoch : 12 Training Cost : 0.012044594
# Epoch : 13 Training Cost : 0.011910043
# Epoch : 14 Training Cost : 0.011611586
# Epoch : 15 Training Cost : 0.011730174
# Epoch : 16 Training Cost : 0.01146443
# Epoch : 17 Training Cost : 0.011560331
# Epoch : 18 Training Cost : 0.013015665
# Epoch : 19 Training Cost : 0.011351827
# Epoch : 20 Training Cost : 0.011419627
# Epoch : 21 Training Cost : 0.01153879
# Epoch : 22 Training Cost : 0.011450861
# Epoch : 23 Training Cost : 0.01144996
# Epoch : 24 Training Cost : 0.011494875
# Epoch : 25 Training Cost : 0.012296469
# Epoch : 26 Training Cost : 0.011656987
# Epoch : 27 Training Cost : 0.011286139
# Epoch : 28 Training Cost : 0.011928013
# Epoch : 29 Training Cost : 0.011224273
# Epoch : 30 Training Cost : 0.011495516
# Epoch : 31 Training Cost : 0.011404726
# Epoch : 32 Training Cost : 0.01139862
# Epoch : 33 Training Cost : 0.011777034
# Epoch : 34 Training Cost : 0.011804244
# Epoch : 35 Training Cost : 0.01123025
# Epoch : 36 Training Cost : 0.011507047
# Epoch : 37 Training Cost : 0.011180743
# Epoch : 38 Training Cost : 0.011328693
# Epoch : 39 Training Cost : 0.013027619
# Epoch : 40 Training Cost : 0.011128142
# Epoch : 41 Training Cost : 0.011375673
# Epoch : 42 Training Cost : 0.011143335
# Epoch : 43 Training Cost : 0.01180041
# Epoch : 44 Training Cost : 0.011586715
# Epoch : 45 Training Cost : 0.011238302
# Epoch : 46 Training Cost : 0.010950999
# Epoch : 47 Training Cost : 0.011405845
# Epoch : 48 Training Cost : 0.010899458
# Epoch : 49 Training Cost : 0.01088452
# Epoch : 50 Training Cost : 0.011265776
# Epoch : 51 Training Cost : 0.011003509
# Epoch : 52 Training Cost : 0.01079598
# Epoch : 53 Training Cost : 0.011637415
# Epoch : 54 Training Cost : 0.011237735
# Epoch : 55 Training Cost : 0.010707307
# Epoch : 56 Training Cost : 0.010699301
# Epoch : 57 Training Cost : 0.010765538
# Epoch : 58 Training Cost : 0.01067076
# Epoch : 59 Training Cost : 0.011149096
# Test Data Cost : 0.014878667

# %%
# stores the predicted value for test data using trained ANN model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ', fontsize="14")
plt.xlabel('Time (Months)', fontsize="14")
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  60.948114453683985

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  98.53394355506867

# %%
plt.figure(figsize=[5*1.5,3*1.5])
plt.plot(range(len(train_loss)),train_loss,label="Training loss")
plt.plot(range(len(test_loss)),test_loss,label="testing loss")
plt.legend(loc='best')
plt.ylabel('Mean Square Error (MSE)', fontsize="14")
plt.xlabel('Number of iterations', fontsize="14")
plt.show()
