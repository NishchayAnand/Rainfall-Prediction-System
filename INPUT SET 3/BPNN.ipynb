# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
df = pd.read_excel("INPUT SET 3.xlsx")

# %%
df.head()
# Out:
#      X1    X2    X3    X4     Y
# 0  24.5   0.0  11.2  54.7  40.3
# 1   0.0  11.2  40.3  26.8   0.0
# 2  11.2  40.3   0.0  23.8  70.4
# 3  40.3   0.0  70.4  22.7   2.2
# 4   0.0  70.4   2.2  25.1  68.2

# %%
df.shape
# Out:
# (1344, 5)

# %%
# splitting the remaining data in training data and validation data. 
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.3, shuffle = False)

# %%
# Scaling the data using MinMax Scaler.
scaler = MinMaxScaler()
X_train = scaler.fit_transform(df_train.drop(["Y"],axis=1).values)
Y_train = scaler.fit_transform(df_train["Y"].values.reshape(-1,1))
X_test = scaler.fit_transform(df_test.drop(["Y"],axis=1).values)
Y_test = scaler.fit_transform(df_test["Y"].values.reshape(-1,1))

# %%
print(X_train.shape)
print(Y_train.shape)
print(X_test.shape)
print(Y_test.shape)
# Out:
# (940, 4)
# (940, 1)
# (404, 4)
# (404, 1)

# %%
# function to denormalise the predicted values.
def denormalize(df,norm_data):
    df = df["Y"].values.reshape(-1,1)
    norm_data = norm_data.reshape(-1,1)
    scl = MinMaxScaler()
    a = scl.fit_transform(df)
    new = scl.inverse_transform(norm_data)
    
    return new

# %%
# defining weights and biases for the nn layers.

input_features = 4

W_1 = tf.Variable(tf.random_uniform([input_features,6])) # weights corresponding to first hidden/input layer.
b_1 = tf.Variable(tf.zeros([6]))

W_2 = tf.Variable(tf.random_uniform([6,6])) # weights corresponding to second hidden layer.
b_2 = tf.Variable(tf.zeros([6]))

W_O = tf.Variable(tf.random_uniform([6,1])) # weights corresponding to the output layer
b_O = tf.Variable(tf.zeros([1]))

# %%
def neural_net_model(X_data):
    
    # layer1 = relu(X_data.W_1 + b_1)
    layer_1 = tf.add(tf.matmul(X_data,W_1), b_1)
    layer_1 = tf.nn.relu(layer_1)
    
    # layer2 = relu(layer1.W_2 + b_2)
    layer_2 = tf.add(tf.matmul(layer_1,W_2), b_2)
    layer_2 = tf.nn.relu(layer_2)
    
    # output = layer2.W_O + b_O
    output = tf.add(tf.matmul(layer_2,W_O), b_O)
    
    return output

# %%
x_data = tf.placeholder("float")
y_target = tf.placeholder("float")

# %%
# y_predicted stores the predicted value.
y_predicted = neural_net_model(x_data)

# %%
# loss function = MSE (Mean Square Error)
cost = tf.reduce_mean(tf.square(y_predicted-y_target))

# %%
# Using Gradient Descent as the optimization algorithm.
train = tf.train.GradientDescentOptimizer(0.01).minimize(cost)

# %%
train_loss = []
test_loss = [] 
batch_size =  100

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

#Loop for training the ANN regression model.

for i in range(100):
        
    train_indices = np.random.choice(len(X_train), batch_size, replace=False)
    x = X_train[train_indices]
    y = Y_train[train_indices]
        
    for j in range(x.shape[0]):
        
        sess.run([cost,train],feed_dict={x_data:x[j,:].reshape(1,4), y_target:y[j].reshape(1,1)})
            
    train_loss.append(sess.run(cost, feed_dict={x_data:X_train,y_target:Y_train}))
    test_loss.append(sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
    print('Epoch :',i,'Training Cost :',train_loss[i])
        
# end of for loop for training the model. 

print('Test Data Cost :',sess.run(cost, feed_dict={x_data:X_test,y_target:Y_test}))
# Out:
# Epoch : 0 Training Cost : 0.049635176
# Epoch : 1 Training Cost : 0.03620946
# Epoch : 2 Training Cost : 0.032640837
# Epoch : 3 Training Cost : 0.029689519
# Epoch : 4 Training Cost : 0.03221299
# Epoch : 5 Training Cost : 0.025978457
# Epoch : 6 Training Cost : 0.023821834
# Epoch : 7 Training Cost : 0.021859156
# Epoch : 8 Training Cost : 0.02088867
# Epoch : 9 Training Cost : 0.019320875
# Epoch : 10 Training Cost : 0.017304813
# Epoch : 11 Training Cost : 0.01637899
# Epoch : 12 Training Cost : 0.015710022
# Epoch : 13 Training Cost : 0.015516017
# Epoch : 14 Training Cost : 0.014874412
# Epoch : 15 Training Cost : 0.014663161
# Epoch : 16 Training Cost : 0.0136357695
# Epoch : 17 Training Cost : 0.0133053465
# Epoch : 18 Training Cost : 0.013470004
# Epoch : 19 Training Cost : 0.012896818
# Epoch : 20 Training Cost : 0.013516352
# Epoch : 21 Training Cost : 0.01234815
# Epoch : 22 Training Cost : 0.013107415
# Epoch : 23 Training Cost : 0.012329282
# Epoch : 24 Training Cost : 0.011956638
# Epoch : 25 Training Cost : 0.01196864
# Epoch : 26 Training Cost : 0.011791199
# Epoch : 27 Training Cost : 0.011767591
# Epoch : 28 Training Cost : 0.011869974
# Epoch : 29 Training Cost : 0.0116286455
# Epoch : 30 Training Cost : 0.011993863
# Epoch : 31 Training Cost : 0.011573633
# Epoch : 32 Training Cost : 0.011903572
# Epoch : 33 Training Cost : 0.011483741
# Epoch : 34 Training Cost : 0.011302569
# Epoch : 35 Training Cost : 0.011908781
# Epoch : 36 Training Cost : 0.011209273
# Epoch : 37 Training Cost : 0.011376135
# Epoch : 38 Training Cost : 0.011157635
# Epoch : 39 Training Cost : 0.011138709
# Epoch : 40 Training Cost : 0.010973756
# Epoch : 41 Training Cost : 0.011007622
# Epoch : 42 Training Cost : 0.010960347
# Epoch : 43 Training Cost : 0.010891167
# Epoch : 44 Training Cost : 0.011156715
# Epoch : 45 Training Cost : 0.0112253325
# Epoch : 46 Training Cost : 0.011373699
# Epoch : 47 Training Cost : 0.010970142
# Epoch : 48 Training Cost : 0.011017401
# Epoch : 49 Training Cost : 0.010773117
# Epoch : 50 Training Cost : 0.010893972
# Epoch : 51 Training Cost : 0.012199142
# Epoch : 52 Training Cost : 0.012006782
# Epoch : 53 Training Cost : 0.010888598
# Epoch : 54 Training Cost : 0.010709691
# Epoch : 55 Training Cost : 0.010696702
# Epoch : 56 Training Cost : 0.010921944
# Epoch : 57 Training Cost : 0.010913119
# Epoch : 58 Training Cost : 0.011584279
# Epoch : 59 Training Cost : 0.010743298
# Epoch : 60 Training Cost : 0.010677577
# Epoch : 61 Training Cost : 0.010836044
# Epoch : 62 Training Cost : 0.010805991
# Epoch : 63 Training Cost : 0.010665404
# Epoch : 64 Training Cost : 0.01099714
# Epoch : 65 Training Cost : 0.01059321
# Epoch : 66 Training Cost : 0.010732145
# Epoch : 67 Training Cost : 0.010572048
# Epoch : 68 Training Cost : 0.011425124
# Epoch : 69 Training Cost : 0.01064775
# Epoch : 70 Training Cost : 0.01067914
# Epoch : 71 Training Cost : 0.01085046
# Epoch : 72 Training Cost : 0.010576467
# Epoch : 73 Training Cost : 0.011369355
# Epoch : 74 Training Cost : 0.010589536
# Epoch : 75 Training Cost : 0.012207415
# Epoch : 76 Training Cost : 0.01049468
# Epoch : 77 Training Cost : 0.010568234
# Epoch : 78 Training Cost : 0.0106695
# Epoch : 79 Training Cost : 0.011246796
# Epoch : 80 Training Cost : 0.01078421
# Epoch : 81 Training Cost : 0.011072587
# Epoch : 82 Training Cost : 0.01217567
# Epoch : 83 Training Cost : 0.010492977
# Epoch : 84 Training Cost : 0.013108062
# Epoch : 85 Training Cost : 0.011213965
# Epoch : 86 Training Cost : 0.010427485
# Epoch : 87 Training Cost : 0.011137285
# Epoch : 88 Training Cost : 0.010409922
# Epoch : 89 Training Cost : 0.01060191
# Epoch : 90 Training Cost : 0.010430831
# Epoch : 91 Training Cost : 0.010467951
# Epoch : 92 Training Cost : 0.010602715
# Epoch : 93 Training Cost : 0.010551147
# Epoch : 94 Training Cost : 0.011015187
# Epoch : 95 Training Cost : 0.010498205
# Epoch : 96 Training Cost : 0.010453676
# Epoch : 97 Training Cost : 0.010518416
# Epoch : 98 Training Cost : 0.012132964
# Epoch : 99 Training Cost : 0.0104183825
# Test Data Cost : 0.0131649105

# %%
# stores the predicted value for test data using trained ANN model.
pred = sess.run(y_predicted, feed_dict={x_data:X_test}) # output comes between 0 to 1.

# %%
# denormalizing our predicted value.
y_test = denormalize(df_test, Y_test)
pred = denormalize(df_test, pred)

# %%
# plot showing difference between actual test data and predicted test data
plt.figure(figsize=[10,6])
plt.plot(range(y_test.shape[0]),y_test,label="Original Data")
plt.plot(range(y_test.shape[0]),pred,label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Intensity of Rainfall (in mm) ')
plt.xlabel('Time (Months)')
plt.show()

# %%
# plot showing difference between actual test data and predicted test data for first 100 samples.
plt.figure(figsize=[20,8])
plt.plot(range(100),y_test[:100],label="Original Data")
plt.plot(range(100),pred[:100],label="Predicted Data")
plt.legend(loc='best')
plt.ylabel('Amount of Rainfall ')
plt.xlabel('Months')
plt.title('Amount of Rainfall ')
plt.show()

# %%
print("MAE : ", np.mean(abs(y_test-pred)))
# Out:
# MAE :  55.63192297043187

# %%
print("RMSE : ", np.sqrt(np.mean(np.square(y_test-pred))))
# Out:
# RMSE :  92.68571585955563

# %%
plt.figure(figsize=[10,5])
plt.plot(range(len(train_loss)),train_loss,label="Training loss")
plt.plot(range(len(test_loss)),test_loss,label="testing loss")
plt.legend(loc='best')
plt.ylabel('Mean Square Error (MSE)')
plt.xlabel('Number of iterations')
plt.title('Loss function')
plt.show()
